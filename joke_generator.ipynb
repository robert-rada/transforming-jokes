# %%
# %tensorflow_version 1.x
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files

from google.colab import drive
# Out:
# TensorFlow 1.x selected.
#   Building wheel for gpt-2-simple (setup.py) ... done
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
gpt2.download_gpt2(model_name="355M")

gpt2.mount_gdrive()

file_name = "comments.txt"
RUN_NAME = "comments1"

gpt2.copy_file_from_gdrive(file_name)
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 343Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 65.4Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 278Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:08, 159Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 360Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 91.1Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 104Mit/s]

# %%
drive.mount('/content/gdrive')

sess = gpt2.start_tf_sess()

gpt2.finetune(sess,
              dataset=file_name,
              model_name='355M',
              steps=-1,
              restore_from='latest',
              run_name=RUN_NAME,
              print_every=50,
              sample_every=1000,
              save_every=500,
              learning_rate=0.00001,
              checkpoint_dir='/content/gdrive/My Drive/generator_models/',
              overwrite=True,
              )
# Out:
# Mounted at /content/gdrive
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/memory_saving_gradients.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# Loading checkpoint /content/gdrive/My Drive/generator_models/comments1/model-24018
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/generator_models/comments1/model-24018
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [01:56<00:00, 116.60s/it]
# dataset has 23191600 tokens
# Training...
# Saving /content/gdrive/My Drive/generator_models/comments1/model-24018
# [24050 | 117.44] loss=1.02 avg=1.02
# [24100 | 269.00] loss=1.34 avg=1.18
# [24150 | 420.62] loss=1.24 avg=1.20
# [24200 | 572.17] loss=1.15 avg=1.19
# [24250 | 723.85] loss=1.00 avg=1.15
# [24300 | 875.50] loss=1.34 avg=1.18
# [24350 | 1027.39] loss=1.30 avg=1.20
# [24400 | 1178.91] loss=1.30 avg=1.21
# [24450 | 1330.69] loss=1.45 avg=1.24
# [24500 | 1482.50] loss=1.16 avg=1.23
# Saving /content/gdrive/My Drive/generator_models/comments1/model-24500
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# [24550 | 1642.68] loss=1.73 avg=1.28
# [24600 | 1793.83] loss=1.31 avg=1.28
# [24650 | 1944.64] loss=1.23 avg=1.28
# [24700 | 2095.57] loss=1.38 avg=1.29
# [24750 | 2246.62] loss=1.22 avg=1.28
# [24800 | 2397.75] loss=1.14 avg=1.27
# [24850 | 2549.50] loss=1.32 avg=1.28
# [24900 | 2701.14] loss=1.21 avg=1.27
# [24950 | 2852.84] loss=1.30 avg=1.27
# [25000 | 3004.35] loss=1.25 avg=1.27
# Saving /content/gdrive/My Drive/generator_models/comments1/model-25000
# ======== SAMPLE 1 ========
#  China was like the Titanic, because there were only 14 survivors. <|startofcomment|> Lol, that was good.... just took a while to sink in <|endoftext|>
# <|startoftext|> I was reading a book about a boy who grew up in China... <|endoftitle|> ...but when he got to high school he forgot what he was... <|startofcomment|> No one forgot about this book <|endoftext|>
# <|startoftext|> Who invented the condom? <|endoftitle|> The first woman to get naked in the bed, covered in spit and urine, did so as she held her rapist's naked cock.  <|startofcomment|> Did she get paid for it? <|endoftext|>
# <|startoftext|> Who invented the condom? <|endoftitle|> The first woman to get naked in the bed, covered in spit and urine, did so as she held her rapist's naked cock.  <|startofcomment|> I'm sure this joke made its way into the newscaster rotation <|endoftext|>
# <|startoftext|> A guy sits at the piano. <|endoftitle|> The piano prods him with a question: "Hey, what instrument are you playing?"
#
# The guy responds: "I'm playing a minor in my cello."  It was at that moment that the world revolved around him... <|startofcomment|> *The world revolved around *him, because he just had a minor! <|endoftext|>
# <|startoftext|> I told my dog to get rid of his old clothes. <|endoftitle|> He was too short to do so. <|startofcomment|> You should give him a bath. <|endoftext|>
# <|startoftext|> I told my dog to get rid of his old clothes. <|endoftitle|> He was too short to do so. <|startofcomment|> I hope he doesn't have to keep the fish for bait. <|endoftext|>
# <|startoftext|> The joke here is... <|endoftitle|> It is a joke, what I think you'd expect.
# So when it comes to a joke, it is a *Joke*. <|startofcomment|> I don't get it <|endoftext|>
# <|startoftext|> A pirate walks into a bar. <|endoftitle|> There's a pirate with a stutter walking into a bar. The bartender says "Hey, you're not supposed to be here."
#
# The pirate says "Wha? What do you mean??"
# The bartender turns to him and says "You're not supposed to be here either".
#
# "But I said I'm pirate!"
#
# The pirate says "Nope. You're not supposed to be here either." <|startofcomment|> But I'm a pirate. I pirate everywhere! <|endoftext|>
# <|startoftext|> Why cannot your parents be in heaven? <|endoftitle|> Because they can't find a wife <|startofcomment|> Oh, I see <|endoftext|>
# <|startoftext|> I can count on one hand the number of times my parents have done this. <|endoftitle|> 5 <|startofcomment|> You might get one right!  <|endoftext|>
# <|startoftext|> What's the difference between an egg and a priest? <|endoftitle|> You can actually get an egg out of a priest! <|startofcomment|> One way or the other, they always get you laid <|endoftext|>
# <|startoftext|> What's the difference between an egg and a priest? <|endoftitle|> You can actually get an egg out of a priest! <|startofcomment|> You have to have a nice big one to get a priest? <|endoftext|>
# <|startoftext|> What do you call three dicks that go out to dinner? <|endoftitle|> Three Dicks  <|startofcomment|> You'll never guess what they were called before <|endoftext|>
# <|startoftext|> What do you call three dicks that go out to dinner? <|endoftitle|> Three Dicks  <|startofcomment|> A dinner party? <|endoftext|>
# <|startoftext|> Did you hear about the man who had a stroke? <|endoft
#
# [25050 | 3207.38] loss=1.07 avg=1.26
# [25100 | 3359.03] loss=1.13 avg=1.25
# [25150 | 3510.62] loss=1.15 avg=1.25
# [25200 | 3662.17] loss=1.39 avg=1.26
# [25250 | 3813.68] loss=1.52 avg=1.27
# [25300 | 3965.28] loss=1.01 avg=1.26
# [25350 | 4116.89] loss=1.31 avg=1.26
# [25400 | 4268.54] loss=1.19 avg=1.26
# [25450 | 4420.50] loss=1.49 avg=1.26
# [25500 | 4572.28] loss=1.19 avg=1.26
# Saving /content/gdrive/My Drive/generator_models/comments1/model-25500
# [25550 | 4732.47] loss=1.63 avg=1.28
# [25600 | 4884.53] loss=1.46 avg=1.28
# [25650 | 5036.51] loss=1.23 avg=1.28
# [25700 | 5188.49] loss=1.33 avg=1.28
# [25750 | 5340.61] loss=1.60 avg=1.29
# [25800 | 5492.67] loss=1.12 avg=1.29
# [25850 | 5644.77] loss=1.37 avg=1.29
# [25900 | 5796.72] loss=1.38 avg=1.29
# [25950 | 5948.74] loss=1.30 avg=1.29
# [26000 | 6100.80] loss=1.38 avg=1.30
# Saving /content/gdrive/My Drive/generator_models/comments1/model-26000
# ======== SAMPLE 1 ========
#  blindness to tell the truth <|endoftitle|> But it's hard to see eye to eye with him. <|startofcomment|> I just gave a handjob to him  <|endoftext|>
# <|startoftext|> I've been trying to get down to earth since I was a baby. <|endoftitle|> But I just can't work up the nerve to do so. <|startofcomment|> He's just like my mother <|endoftext|>
# <|startoftext|> What do you call a woman that's too fat to play basketball? <|endoftitle|> An air force captain. <|startofcomment|> I see what you did there <|endoftext|>
# <|startoftext|> What do you call a woman that's too fat to play basketball? <|endoftitle|> An air force captain. <|startofcomment|> Too fat to play "basketball"? You can do soccer though.
#
#   <|endoftext|>
# <|startoftext|> "What can I get you from here?" <|endoftitle|> "A better car." <|startofcomment|> How sweet. <|endoftext|>
# <|startoftext|> In the beginning there was darkness. <|endoftitle|> And God said, "Let there be light." <|startofcomment|> "Shoot first"
#
# Got it :D;) <|endoftext|>
# <|startoftext|> What's the best thing about riding an elevator? <|endoftitle|> You don't have to stand in a small circle to hear the elevator pitch. <|startofcomment|> This actually happened.   <|endoftext|>
# <|startoftext|> I tried to have sex with a group of people. <|endoftitle|> I kept getting called "a child actor". <|startofcomment|> Haha that's great  <|endoftext|>
# <|startoftext|> Why would a chicken jump into a swimming pool? <|endoftitle|> Because he hates the water. <|startofcomment|> The water tastes salty?   <|endoftext|>
# <|startoftext|> What do you call a man with a parrot's head on his shoulder? <|endoftitle|> Dick Tracy!!! <|startofcomment|> Dick Tracy the movie.  <|endoftext|>
# <|startoftext|> I asked my wife "Do you have a pet rock?" <|endoftitle|> She said "No" and started crying. I said"That explains most of your problems"  <|startofcomment|> "You're nuts" - me <|endoftext|>
# <|startoftext|> I asked my wife "Do you have a pet rock?" <|endoftitle|> She said "No" and started crying. I said"That explains most of your problems"  <|startofcomment|> "You're nuts"
#
#  <|endoftext|>
# <|startoftext|> I asked my wife "Do you have a pet rock?" <|endoftitle|> She said "No" and started crying. I said"That explains most of your problems"  <|startofcomment|> r/ComedyCemetery <|endoftext|>
# <|startoftext|> What does a gynecologist have in common with a woman who lies about her period? <|endoftitle|> Period.  <|startofcomment|> "You're such a whores asshole." <|endoftext|>
# <|startoftext|> What do you get when you cross a pig and an onion? <|endoftitle|> Brie meat.  <|startofcomment|> Brie meat? Puts some bacon in. <|endoftext|>
# <|startoftext|> Did you know that they're experimenting with a new type of bullet? <|endoftitle|> It is a silencer. <|startofcomment|> I bet that's how the Germans came to the US in the 19th century <|endoftext|>
# <|startoftext|> Did you know that they're experimenting with a new type of bullet? <|endoftitle|> It is a silencer. <|startofcomment|> It could also be a silencer <|endoftext|>
# <|startoftext|> My wife said I should stop speaking Russian. <|endoftitle|> I explained it's a very
#
# [26050 | 6303.27] loss=1.00 avg=1.29
# [26100 | 6455.37] loss=1.40 avg=1.29
# [26150 | 6607.29] loss=1.05 avg=1.28
# [26200 | 6759.30] loss=1.42 avg=1.29
# [26250 | 6911.35] loss=1.23 avg=1.29
# [26300 | 7063.46] loss=1.43 avg=1.29
# [26350 | 7215.58] loss=1.22 avg=1.29
# [26400 | 7367.66] loss=1.40 avg=1.29
# [26450 | 7519.65] loss=1.29 avg=1.29
# [26500 | 7671.80] loss=1.37 avg=1.29
# Saving /content/gdrive/My Drive/generator_models/comments1/model-26500
# [26550 | 7835.65] loss=1.32 avg=1.29
# [26600 | 7987.62] loss=1.37 avg=1.29
# [26650 | 8139.80] loss=1.22 avg=1.29
# [26700 | 8291.71] loss=1.34 avg=1.29
# [26750 | 8444.02] loss=1.24 avg=1.29
# [26800 | 8596.30] loss=1.46 avg=1.30
# [26850 | 8747.82] loss=1.28 avg=1.30
# [26900 | 8898.39] loss=1.02 avg=1.29
# [26950 | 9049.02] loss=1.41 avg=1.29
# [27000 | 9199.62] loss=1.34 avg=1.29
# Saving /content/gdrive/My Drive/generator_models/comments1/model-27000
# ======== SAMPLE 1 ========
#  creepy jokes <|endoftext|>
# <|startoftext|> Where's a guy who says the word "I" and doesn't get the correct answer? <|endoftitle|> The guy who says "I believe I." <|startofcomment|> I'm so sorry <|endoftext|>
# <|startoftext|> Where's a guy who says the word "I" and doesn't get the correct answer? <|endoftitle|> The guy who says "I believe I." <|startofcomment|> This sub is getting old <|endoftext|>
# <|startoftext|> How did the French fry disappear? <|endoftitle|> they got a potato. <|startofcomment|> They're so hot right now. <|endoftext|>
# <|startoftext|> I took my guitar out for a spin today <|endoftitle|> I wasn't sure if I should strum it a little bit or not, then I realized a guy was driving a Ford Focus.
#
# I stopped him and we all gushed about how I'm going to one day be a legend with my guitar. <|startofcomment|> And I got laid by an African girl! <|endoftext|>
# <|startoftext|> I took my guitar out for a spin today <|endoftitle|> I wasn't sure if I should strum it a little bit or not, then I realized a guy was driving a Ford Focus.
#
# I stopped him and we all gushed about how I'm going to one day be a legend with my guitar. <|startofcomment|> you should play that song before you play it? <|endoftext|>
# <|startoftext|> I took my guitar out for a spin today <|endoftitle|> I wasn't sure if I should strum it a little bit or not, then I realized a guy was driving a Ford Focus.
#
# I stopped him and we all gushed about how I'm going to one day be a legend with my guitar. <|startofcomment|> You'll be a legend once you can bend down.
#  <|endoftext|>
# <|startoftext|> I took my guitar out for a spin today <|endoftitle|> I wasn't sure if I should strum it a little bit or not, then I realized a guy was driving a Ford Focus.
#
# I stopped him and we all gushed about how I'm going to one day be a legend with my guitar. <|startofcomment|> The man is a legend. I bet his guitar is the best <|endoftext|>
# <|startoftext|> I'm still going to sleep next to my best friend's grave <|endoftitle|> But I'm afraid I'll be too loud about it. <|startofcomment|> I'm tired of that. <|endoftext|>
# <|startoftext|> I think I'm in over my head and just got fired from my last job <|endoftitle|> I finally just quit my job... I can't even get a raise or give back the money I lost... <|startofcomment|> And the company is making sure there isn't a repeat of this. <|endoftext|>
# <|startoftext|> A man is getting ready for his daily jog <|endoftitle|> When he sees some black guy running with a stick, he stops him and says, "Look, I'm your coach!"
# But the black guy turns away and says, "Who are you and what do you need a coach for?"
# The man then realized that he is the coach and tells the black guy to get lost. <|startofcomment|> ...and then the guy left <|endoftext|>
# <|startoftext|> A man is getting ready for his daily jog <|endoftitle|> When he sees some black guy running with a stick, he stops him and says, "Look, I'm your coach!"
# But the black guy turns away and says, "Who are you and what do you need a coach for?"
# The man then realized that he is the coach and tells the black guy to get lost. <|startofcomment|> Ohm my gosh ! I can't believe you... <|endoftext|>
# <|startoftext|> Why do you never hear politicians call a bill a bill? <|endoftitle|> Because their fingers are usually on the docket. <|startofcomment|> Because they're all a-sides. <|endoftext|>
# <|startoftext|> A man asks
#
# [27050 | 9399.94] loss=1.59 avg=1.30
# [27100 | 9550.58] loss=1.02 avg=1.29
# [27150 | 9701.20] loss=1.13 avg=1.29
# [27200 | 9851.78] loss=1.17 avg=1.29
# [27250 | 10002.31] loss=1.04 avg=1.28
# [27300 | 10152.90] loss=1.47 avg=1.29
# [27350 | 10303.54] loss=1.14 avg=1.28
# [27400 | 10454.12] loss=1.58 avg=1.29
# [27450 | 10604.73] loss=1.23 avg=1.29
# [27500 | 10755.31] loss=1.10 avg=1.29
# Saving /content/gdrive/My Drive/generator_models/comments1/model-27500
# [27550 | 10915.50] loss=1.11 avg=1.28
# [27600 | 11065.76] loss=1.13 avg=1.28
# [27650 | 11215.96] loss=1.28 avg=1.28
# [27700 | 11366.62] loss=1.43 avg=1.28
# [27750 | 11517.37] loss=1.61 avg=1.29
# [27800 | 11668.19] loss=1.22 avg=1.29
# [27850 | 11818.96] loss=0.86 avg=1.28
# [27900 | 11969.68] loss=1.01 avg=1.27
# [27950 | 12120.43] loss=1.40 avg=1.28
# [28000 | 12271.38] loss=1.47 avg=1.28
# Saving /content/gdrive/My Drive/generator_models/comments1/model-28000
# ======== SAMPLE 1 ========
#  <|endoftext|>
# <|startoftext|> Why can't you hear a pterodactyl using the bathroom? <|endoftitle|> Because their P is silent <|startofcomment|> Isnt that supposed to be "P" <|endoftext|>
# <|startoftext|> Why can't you hear a pterodactyl using the bathroom? <|endoftitle|> Because their P is silent <|startofcomment|> *"So-so"* <|endoftext|>
# <|startoftext|> You know what sucks? <|endoftitle|> Air. <|startofcomment|> Don't you mean air? <|endoftext|>
# <|startoftext|> Whats the difference between a chickpea and a lentil? <|endoftitle|> I'll never pay to have a lentil on my face. <|startofcomment|> Lol, I can't imagine the pain of a lentil  <|endoftext|>
# <|startoftext|> Whats the difference between a chickpea and a lentil? <|endoftitle|> I'll never pay to have a lentil on my face. <|startofcomment|> Lol, I can't imagine the pain of a lentil  <|endoftext|>
# <|startoftext|> Whats the difference between a chickpea and a lentil? <|endoftitle|> I'll never pay to have a lentil on my face. <|startofcomment|> Lol, you can't have a lentil on my face <|endoftext|>
# <|startoftext|> Whats the difference between a chickpea and a lentil? <|endoftitle|> I'll never pay to have a lentil on my face. <|startofcomment|> LOL, I can't imagine the pain of a lentil  <|endoftext|>
# <|startoftext|> Whats the difference between a chickpea and a lentil? <|endoftitle|> I'll never pay to have a lentil on my face. <|startofcomment|> Lol, I can't imagine the pain of a lentil  <|endoftext|>
# <|startoftext|> Whats the difference between a chickpea and a lentil? <|endoftitle|> I'll never pay to have a lentil on my face. <|startofcomment|> Lol, I can't imagine the pain of a lentil  <|endoftext|>
# <|startoftext|> whats the best way to eat a clown... <|endoftitle|> with your hands... <|startofcomment|> Don't eat all in one go. Use a spoon or fork... <|endoftext|>
# <|startoftext|> Whats the best way to eat a clown... <|endoftitle|> with your hands... <|startofcomment|> Use a spoon or fork... <|endoftext|>
# <|startoftext|> What do you call a woman with no legs? <|endoftitle|> You'd be wrong though. I don't know her or why she's calling me stupid. <|startofcomment|> What do you call a woman with no arms?
#
# My boyfriend. <|endoftext|>
# <|startoftext|> What did the farmer say to his son before they had a fight? <|endoftitle|> "What did you do to my weed?" <|startofcomment|> The father was the gardener and the son was the weed. <|endoftext|>
# <|startoftext|> The other day my wife said, "When I die I want you to pull on my dress to determine if she has a heart-attack" I said, "I'll do her, but when you take off her clothes I want you to go downstairs and tell me she has an epileptic seizure." <|endoftitle|> She didn't.  <|startofcomment|> Do you want some fresh air? <|endoftext|>
# <|startoftext|> The other day my wife said, "When I die I want you to pull on my dress to determine if she has a heart-attack" I said, "I'll do her, but when you take off her clothes I want you to go downstairs and tell me she has an epileptic seizure." <|endoftitle|> She didn't.  <|startofcomment|> Are you saying her legs are not as well worn? <|endoftext|>
# <|
#
# [28050 | 12469.97] loss=1.22 avg=1.28
# [28100 | 12620.93] loss=0.94 avg=1.27
# [28150 | 12771.94] loss=1.49 avg=1.28
# [28200 | 12923.07] loss=1.48 avg=1.28
# [28250 | 13074.21] loss=1.23 avg=1.28
# [28300 | 13225.31] loss=1.29 avg=1.28
# [28350 | 13376.45] loss=1.58 avg=1.28
# [28400 | 13527.55] loss=1.31 avg=1.28
# [28450 | 13678.66] loss=1.04 avg=1.28
# [28500 | 13829.78] loss=1.14 avg=1.28
# Saving /content/gdrive/My Drive/generator_models/comments1/model-28500
# [28550 | 13992.25] loss=1.36 avg=1.28
# [28600 | 14143.23] loss=1.18 avg=1.28
# [28650 | 14294.22] loss=1.01 avg=1.27
# [28700 | 14445.21] loss=1.22 avg=1.27
# [28750 | 14596.07] loss=1.31 avg=1.27
# [28800 | 14746.87] loss=1.29 avg=1.27
# [28850 | 14897.54] loss=2.24 avg=1.29
# [28900 | 15048.25] loss=1.41 avg=1.29
# [28950 | 15199.08] loss=1.51 avg=1.29
# [29000 | 15349.80] loss=1.21 avg=1.29
# Saving /content/gdrive/My Drive/generator_models/comments1/model-29000
# ======== SAMPLE 1 ========
# comment|> i'm sorry <|endoftext|>
# <|startoftext|> I always thought the people I'm always sad for are bad at poker <|endoftitle|> But now I'm not so sure <|startofcomment|> It is true <|endoftext|>
# <|startoftext|> I hate it when my wife asks me to make the bed and my face makes her wake up with a headache <|endoftitle|> I should probably check my pillow for the sleeping pill after all. <|startofcomment|> I love you,  <|endoftext|>
# <|startoftext|> A guy in the army got hit last week <|endoftitle|> He's fighting back today... <|startofcomment|> "I see you're a big fan of the American Football." <|endoftext|>
# <|startoftext|> A guy in the army got hit last week <|endoftitle|> He's fighting back today... <|startofcomment|> But where ? <|endoftext|>
# <|startoftext|> A guy in the army got hit last week <|endoftitle|> He's fighting back today... <|startofcomment|> r/angryupvote <|endoftext|>
# <|startoftext|> Why did the priest leave his bible in the toilet? <|endoftitle|> He ran out of shit to take the Lord's face.
#  <|startofcomment|> OOOOOO, that's a good one! <|endoftext|>
# <|startoftext|> What is a cow's favourite kind of cake? <|endoftitle|> Cheeze. <|startofcomment|> I love you <|endoftext|>
# <|startoftext|> I have this horrible feeling that I hate my computer keyboard <|endoftitle|> It constantly comes up with really weird passwords. <|startofcomment|> "I Hate My PC" <|endoftext|>
# <|startoftext|> When you think of "funny" you picture it <|endoftitle|> The same thing is funny when you think of "fat."
#
#
#
#
#
#
#
# They are both a description of the same individual. <|startofcomment|> I thought they are not identical? <|endoftext|>
# <|startoftext|> Why doesn't Santa Claus have any children? <|endoftitle|> Because the kid's on his own. <|startofcomment|> I thought the joke was that he has nothing to do with the children? <|endoftext|>
# <|startoftext|> So a group of people got in a fight at a fancy restaurant with a bunch of women... <|endoftitle|> Some guy in the front row was trying to make a scene at the "Bartender".
#
# Apparently his friend in the back row wasn't so lucky and got punched in the face.
#
# The loser was a bartender, his friends were his bar staff. <|startofcomment|> They can drink like gangbangers. <|endoftext|>
# <|startoftext|> I've started dating a girl from Russia the other day... <|endoftitle|> She has the whole package <|startofcomment|> It's a shame because of the way she dances.  <|endoftext|>
# <|startoftext|> I've started dating a girl from Russia the other day... <|endoftitle|> She has the whole package <|startofcomment|> She would definitely want no more. <|endoftext|>
# <|startoftext|> I've started dating a girl from Russia the other day... <|endoftitle|> She has the whole package <|startofcomment|> What are the odds of us becoming family in Russia? <|endoftext|>
# <|startoftext|> Why can't Superman go to the bathroom? <|endoftitle|> Because the toilet on his home world is actually empty of shit. <|startofcomment|> He couldn't pee because his body is too weak. <|endoftext|>
# <|startoftext|> Why can't Superman go to the bathroom? <|endoftitle|> Because the toilet on his home world is actually empty of shit. <|startofcomment|> He's dead <|endoftext|>
# <|startoftext|> My friend says he has been a vegetarian for over 45 yrs. <|endoftitle|> I asked him "where did you get so many
#
# [29050 | 15547.83] loss=1.08 avg=1.29
# [29100 | 15698.65] loss=1.10 avg=1.29
# [29150 | 15849.41] loss=1.37 avg=1.29
# [29200 | 16000.10] loss=1.00 avg=1.28
# [29250 | 16150.84] loss=0.75 avg=1.28
# [29300 | 16301.54] loss=1.26 avg=1.28
# [29350 | 16452.24] loss=1.11 avg=1.27
# [29400 | 16603.08] loss=1.18 avg=1.27
# [29450 | 16753.86] loss=1.43 avg=1.27
# [29500 | 16904.75] loss=0.98 avg=1.27
# Saving /content/gdrive/My Drive/generator_models/comments1/model-29500
# [29550 | 17064.03] loss=1.47 avg=1.27
# [29600 | 17214.85] loss=1.20 avg=1.27
# [29650 | 17365.65] loss=1.53 avg=1.28
# [29700 | 17516.44] loss=1.28 avg=1.28
# [29750 | 17667.25] loss=1.06 avg=1.27
# [29800 | 17818.08] loss=1.34 avg=1.27
# [29850 | 17969.20] loss=1.09 avg=1.27
# [29900 | 18120.31] loss=1.26 avg=1.27
# [29950 | 18271.42] loss=1.33 avg=1.27
# [30000 | 18422.51] loss=1.49 avg=1.27
# Saving /content/gdrive/My Drive/generator_models/comments1/model-30000
# ======== SAMPLE 1 ========
# <|startoftext|> What is the best way to catch a dolphin? <|endoftitle|> Swim. <|startofcomment|> If you can't do it with a net.  <|endoftext|>
# <|startoftext|> The most recent case of a serial rapist was caught... <|endoftitle|> in Canada. <|startofcomment|> Can confirm. <|endoftext|>
# <|startoftext|> The reason why I have a girlfriend is because I have very high standards. <|endoftitle|> Like, I only give her a 5/3. <|startofcomment|> The average male is 5/10. <|endoftext|>
# <|startoftext|> The man I'm dating wants to know my life plan for the future. <|endoftitle|> I have two plan Bs. <|startofcomment|> Ouch <|endoftext|>
# <|startoftext|> I saw my friend's girlfriend having an argument with her boyfriend... <|endoftitle|> So I yelled at her
# "No you're not the one"
# She backed off and started walking away, and I yelled "Hey, you can't walk away from an argument with an argument!" <|startofcomment|> ...in court. <|endoftext|>
# <|startoftext|> I saw my friend's girlfriend having an argument with her boyfriend... <|endoftitle|> So I yelled at her
# "No you're not the one"
# She backed off and started walking away, and I yelled "Hey, you can't walk away from an argument with an argument!" <|startofcomment|> This is the kind of thing you get at homeopathy clinics. <|endoftext|>
# <|startoftext|> I saw my friend's girlfriend having an argument with her boyfriend... <|endoftitle|> So I yelled at her
# "No you're not the one"
# She backed off and started walking away, and I yelled "Hey, you can't walk away from an argument with an argument!" <|startofcomment|> i thought about it for awhile then laughed out loud <|endoftext|>
# <|startoftext|> I saw my friend's girlfriend having an argument with her boyfriend... <|endoftitle|> So I yelled at her
# "No you're not the one"
# She backed off and started walking away, and I yelled "Hey, you can't walk away from an argument with an argument!" <|startofcomment|> Haha <|endoftext|>
# <|startoftext|> I saw my friend's girlfriend having an argument with her boyfriend... <|endoftitle|> So I yelled at her
# "No you're not the one"
# She backed off and started walking away, and I yelled "Hey, you can't walk away from an argument with an argument!" <|startofcomment|> You can't walk away from a wife beating. <|endoftext|>
# <|startoftext|> This is the last weekend of July 2015 <|endoftitle|> So, here's a nice, relaxed, family holiday. <|startofcomment|> Did you make that up this morning? <|endoftext|>
# <|startoftext|> What do you call a bird who has lived a wonderful life and died peacefully in his sleep? <|endoftitle|> A bird who has died peacefully in his sleep. <|startofcomment|> A real life story. <|endoftext|>
# <|startoftext|> What do you call a bird who has lived a wonderful life and died peacefully in his sleep? <|endoftitle|> A bird who has died peacefully in his sleep. <|startofcomment|> This joke is so funny it makes me die peacefully in my sleep. <|endoftext|>
# <|startoftext|> What do you call a bird who has lived a wonderful life and died peacefully in his sleep? <|endoftitle|> A bird who has died peacefully in his sleep. <|startofcomment|> What kind of bird can live quietly in his sleep?
#  <|endoftext|>
# <|startoftext|> A girl walks into a sex shop <|endoftitle|> "Do you have a table and chairs", She asked.
#
# The owner replied, "No. We only have single-ply sheets." <|startofcomment|> I think I laughed more than I should have. <|endoftext|>
# <|startoftext|> What do you call a cow with four legs? <
#
# [30050 | 18619.48] loss=1.23 avg=1.27
# [30100 | 18770.57] loss=1.06 avg=1.27
# [30150 | 18921.63] loss=1.12 avg=1.27
# [30200 | 19072.58] loss=1.07 avg=1.27
# [30250 | 19223.56] loss=1.15 avg=1.26
# [30300 | 19374.55] loss=1.16 avg=1.26
# [30350 | 19525.52] loss=1.14 avg=1.26
# [30400 | 19676.56] loss=1.34 avg=1.26
# [30450 | 19827.61] loss=1.38 avg=1.26
# [30500 | 19978.69] loss=1.30 avg=1.26
# Saving /content/gdrive/My Drive/generator_models/comments1/model-30500
# [30550 | 20139.65] loss=1.20 avg=1.26
# [30600 | 20290.84] loss=1.34 avg=1.26
# [30650 | 20442.03] loss=1.15 avg=1.26
# [30700 | 20593.19] loss=1.13 avg=1.26
# [30750 | 20744.26] loss=0.86 avg=1.26
# [30800 | 20895.44] loss=1.36 avg=1.26
# [30850 | 21046.70] loss=1.32 avg=1.26
# [30900 | 21198.05] loss=1.49 avg=1.26
# [30950 | 21349.30] loss=1.11 avg=1.26
# [31000 | 21500.31] loss=1.41 avg=1.26
# Saving /content/gdrive/My Drive/generator_models/comments1/model-31000
# ======== SAMPLE 1 ========
#  which was just an elaborate joke on my face. <|endoftitle|> So then I realized it was a really good joke, but I couldn't come up with anything funny. <|startofcomment|> You should have thought of that sooner <|endoftext|>
# <|startoftext|> Dad joked my co-worker today. I'll skip the obligatory opening and closing of the mouth <|endoftitle|> My co-worker is a professional drummer. If anyone is wondering, his first name is Phil. <|startofcomment|> Not sure if it works or not <|endoftext|>
# <|startoftext|> Dad joked my co-worker today. I'll skip the obligatory opening and closing of the mouth <|endoftitle|> My co-worker is a professional drummer. If anyone is wondering, his first name is Phil. <|startofcomment|> Nice. <|endoftext|>
# <|startoftext|> If you have 3 apples, ... <|endoftitle|> 2 apples?
#
# Nooooo, you get one apple. <|startofcomment|> And 2 apples?
#
# And 2 apples! <|endoftext|>
# <|startoftext|> If you have 3 apples, ... <|endoftitle|> 2 apples?
#
# Nooooo, you get one apple. <|startofcomment|> Yes, 2 apples you have
#
# Then you have apple <|endoftext|>
# <|startoftext|> If you have 3 apples, ... <|endoftitle|> 2 apples?
#
# Nooooo, you get one apple. <|startofcomment|> Haha! I see what you did wrong. <|endoftext|>
# <|startoftext|> What do you call a pig that's being chased by a pack of wolves? <|endoftitle|> A hare-wolf.  <|startofcomment|> I thought it was the pack of pigs. <|endoftext|>
# <|startoftext|> What do you call a pig that's being chased by a pack of wolves? <|endoftitle|> A hare-wolf.  <|startofcomment|> That was a good one <|endoftext|>
# <|startoftext|> Dad on driving to dinner <|endoftitle|> Dad on driving to dinner - "How long until dessert?" <|startofcomment|> What about dessert? <|endoftext|>
# <|startoftext|> Got told this. <|endoftitle|> Dad on driving to dinner - "How long until dessert?" <|startofcomment|> It's pretty funny :) <|endoftext|>
# <|startoftext|> My dad jokes are really only a dad to me. <|endoftitle|>  <|startofcomment|> I love your dad jokes <|endoftext|>
# <|startoftext|> My dad (joke) <|endoftitle|> My dad (joke) was trying to go to Starbucks.
#
# Dad: Do you want some coffee?
# Mom: No sir, I'll be here all day.
# I'm not sure she'll get the memo. <|startofcomment|> No coffee. I don't get it. <|endoftext|>
# <|startoftext|> Told my Dad to stop getting ants in our house when we visit Japan. <|endoftitle|> Dad: I'm not the one getting ants in my house.
# Me (joking): So that's what you call me?
# Dad: No. I am the apple of his eye. <|startofcomment|> r/DadJokers <|endoftext|>
# <|startoftext|> I told my daughter today that I liked to have sex in the living room <|endoftitle|> We all chuckled and laughed for a moment.
#
# That's how I met the dog. <|startofcomment|> This is so meta... <|endoftext|>
# <|startoftext|> I told my daughter today that I liked to have sex in the living room <|endoftitle|> We all chuckled and laughed for a moment.
#
# That's how I met the dog. <|startofcomment|> It's so old... it belongs in /r/LifeProTips <|endoftext|>
# <|startoftext|> Me: So, what do you want to be when you grow up? <|endoftitle|> Daughter: I'm not sure, I think it will depend upon how I'm raised
#
# [31050 | 21700.68] loss=1.33 avg=1.26
# [31100 | 21851.57] loss=1.15 avg=1.26
# [31150 | 22002.42] loss=1.39 avg=1.26
# [31200 | 22153.18] loss=1.11 avg=1.26
# [31250 | 22303.95] loss=1.05 avg=1.26
# [31300 | 22454.80] loss=1.50 avg=1.26
# [31350 | 22605.59] loss=1.26 avg=1.26
# [31400 | 22756.39] loss=1.23 avg=1.26
# [31450 | 22907.11] loss=1.30 avg=1.26
# [31500 | 23057.81] loss=1.62 avg=1.27
# Saving /content/gdrive/My Drive/generator_models/comments1/model-31500
# [31550 | 23216.91] loss=1.02 avg=1.26
# [31600 | 23367.69] loss=1.35 avg=1.26
# [31650 | 23518.43] loss=0.96 avg=1.26
# [31700 | 23669.14] loss=1.18 avg=1.26
# [31750 | 23819.93] loss=1.03 avg=1.26
