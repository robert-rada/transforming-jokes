# %% [markdown]
# For more about `gpt-2-simple`, you can visit [this GitHub repository](https://github.com/minimaxir/gpt-2-simple). You can also read my [blog post](https://minimaxir.com/2019/09/howto-gpt2/) for more information how to use this notebook!
#
# original:
# https://colab.research.google.com/drive/1VLG8e7YSEwypxU-noRNhsv5dW4NfTGce

# %%
# %tensorflow_version 1.x
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
# Out:
# TensorFlow 1.x selected.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# ## Downloading GPT-2
#
# If you're retraining a model on new text, you need to download the GPT-2 model first.
#
# There are three released sizes of GPT-2:
#
# * `124M` (default): the "small" model, 500MB on disk.
# * `355M`: the "medium" model, 1.5GB on disk.
# * `774M`: the "large" model, cannot currently be finetuned with Colaboratory but can be used to generate text from the pretrained model (see later in Notebook)
# * `1558M`: the "extra large", true model. Will not work if a K80 GPU is attached to the notebook. (like `774M`, it cannot be finetuned).
#
# Larger models have more knowledge, but take longer to finetune and longer to generate text. You can specify which base model to use by changing `model_name` in the cells below.
#
# The next cell downloads it from Google Cloud Storage and saves it in the Colaboratory VM at `/models/<model_name>`.
#
# This model isn't permanently saved in the Colaboratory VM; you'll have to redownload it if you want to retrain it at a later time.

# %%
gpt2.download_gpt2(model_name="355M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 299Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 95.3Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 317Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:10, 136Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 344Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 105Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 146Mit/s]

# %% [markdown]
# ## Mounting Google Drive
#
# The best way to get input text to-be-trained into the Colaboratory VM, and to get the trained model *out* of Colaboratory, is to route it through Google Drive *first*.
#
# Running this cell (which will only work in Colaboratory) will mount your personal Google Drive in the VM, which later cells can use to get data in/out. (it will ask for an auth code; that auth is not saved anywhere)

# %%
gpt2.mount_gdrive()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Uploading a Text File to be Trained to Colaboratory
#
# In the Colaboratory Notebook sidebar on the left of the screen, select *Files*. From there you can upload files:
#
# ![alt text](https://i.imgur.com/TGcZT4h.png)
#
# Upload **any smaller text file**  (<10 MB) and update the file name in the cell below, then run the cell.

# %%
file_name = "dadjokes.txt"

# %% [markdown]
# If your text file is larger than 10MB, it is recommended to upload that file to Google Drive first, then copy that file from Google Drive to the Colaboratory VM.

# %%
gpt2.copy_file_from_gdrive(file_name)

# %% [markdown]
# ## Finetune GPT-2
#
# The next cell will start the actual finetuning of GPT-2. It creates a persistent TensorFlow session which stores the training config, then runs the training for the specified number of `steps`. (to have the finetuning run indefinitely, set `steps = -1`)
#
# The model checkpoints will be saved in `/checkpoint/run1` by default. The checkpoints are saved every 500 steps (can be changed) and when the cell is stopped.
#
# The training might time out after 4ish hours; make sure you end training and save the results so you don't lose them!
#
# **IMPORTANT NOTE:** If you want to rerun this cell, **restart the VM first** (Runtime -> Restart Runtime). You will need to rerun imports but not recopy files.
#
# Other optional-but-helpful parameters for `gpt2.finetune`:
#
#
# *  **`restore_from`**: Set to `fresh` to start training from the base GPT-2, or set to `latest` to restart training from an existing checkpoint.
# * **`sample_every`**: Number of steps to print example output
# * **`print_every`**: Number of steps to print training progress.
# * **`learning_rate`**:  Learning rate for the training. (default `1e-4`, can lower to `1e-5` if you have <1MB input data)
# *  **`run_name`**: subfolder within `checkpoint` to save the model. This is useful if you want to work with multiple models (will also need to specify  `run_name` when loading the model)
# * **`overwrite`**: Set to `True` if you want to continue finetuning an existing model (w/ `restore_from='latest'`) without creating duplicate copies.

# %%
sess = gpt2.start_tf_sess()

gpt2.finetune(sess,
              dataset=file_name,
              model_name='355M',
              steps=5000,
              restore_from='fresh',
              run_name='dadjokes1',
              print_every=10,
              sample_every=200,
              save_every=500,
              learning_rate=0.00001,
              )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/memory_saving_gradients.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# Loading checkpoint models/355M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/355M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:29<00:00, 29.68s/it]
# dataset has 6172526 tokens
# Training...
# [10 | 42.82] loss=2.52 avg=2.52
# [20 | 74.98] loss=2.43 avg=2.47
# [30 | 107.11] loss=2.03 avg=2.32
# [40 | 139.26] loss=1.61 avg=2.14
# [50 | 171.43] loss=1.71 avg=2.05
# [60 | 203.56] loss=2.29 avg=2.10
# [70 | 235.66] loss=2.37 avg=2.14
# [80 | 267.65] loss=1.90 avg=2.11
# [90 | 299.73] loss=1.92 avg=2.08
# [100 | 331.83] loss=2.39 avg=2.12
# [110 | 363.92] loss=2.10 avg=2.11
# [120 | 395.98] loss=1.76 avg=2.08
# [130 | 428.00] loss=1.85 avg=2.06
# [140 | 460.00] loss=2.00 avg=2.06
# [150 | 492.16] loss=1.75 avg=2.04
# [160 | 524.27] loss=1.92 avg=2.03
# [170 | 556.37] loss=1.71 avg=2.01
# [180 | 588.56] loss=1.97 avg=2.01
# [190 | 620.74] loss=1.80 avg=1.99
# [200 | 652.88] loss=2.12 avg=2.00
# ======== SAMPLE 1 ========
# <|startoftext|> Why does it take so long to make a baby's heart? [|startoftext|> When I was a child I used to play the piano and I would try to imitate the chords. [|startoftext|> In a nursery rhyme someone says, "When you hear the first noise, it's the sound of a baby dying." [|startoftext|> My grandparents always joke, "The doctor came and said there is only one medicine with one name." [|startoftext|> I know someone who's always making this joke but it just makes me laugh [|startoftext|> My mom is an advocate [|startoftext|> I found the original title of the old video game by clicking on the image of the poster in that game's game mode. [|startoftext|> I'm trying to create a game with the theme of the song. [|startoftext|> What is a "big toe?" [|startoftext|> Who is in charge of the universe? [|startoftext|> Did you read "Answers" by the Beatles, when they were making a record [|startoftext|> Someone had a nice joke when they saw the Pope visiting a homeless beggar [|startoftext|> What did the Greek god mean when he said that the only word he had left was "fucking." [|startoftext|> I once had a conversation with my grandfather while he was driving, it got really intense when he came to a big red stop sign... [|startoftext|> I'm not sure I'd be a good actor because the "I" and "T"s don't line up well. [|startoftext|> I was going to take an online exam today and just write the answers but I stopped, and then all of a sudden came back the following morning and it was all the answers. My boss said it was great.
#
# 'You need to be careful with your answer and remember that it's a written exam right. '
#
# -L
#
# [|startoftext|> I'm sorry we have had to deal with this. [|startoftext|> I would say to the lady she was making a very funny face to say the word. [|startoftext|> I was about to give my child a bath for dinner and she asked, "Does it get cold in the shower?"
#
# 'Do I want to wash my hands with some liquid soap?" I responded
#
# 'Do I want to use a good shower?' The lady replied
#
# ''you don't need to worry about your hands,"
#
# But I'm not going to be too fond the next time she asks such a question. [|startoftext|> I don't know a single person who would vote for anyone other than the GOP because they don't agree with them [|startoftext|> I'm a huge Republican. [|startoftext|> Did you know everyone who is in the military (in any organization) is born on one of America's two military bases? They call it Bunko! [|startoftext|> Why am I always having to wear these pants when I'm in the bath? [|startoftext|> A couple of weeks ago while listening to a book I couldn't help but think, I wonder what he was reading that I wasn't?
#
# 'I'm sure you'll forgive me the digression, but it appears I'm getting too old for this. This is my favourite section.' [|startoftext|> I was having a hard time putting together what went on today at my school [|startoftext|> How much of our brains does it take to make a sandwich!? [|startoftext|> The people in charge of this restaurant need to get a little more specific. [|startoftext|> I'm taking a break for a while. I think I'll see my dad this summer! ^^ #shrug [|startoftext|> A friend of mine had cancer and it's being treated very poorly right now [|startoftext|> A few years ago, a family member told me that for years, your parents probably said the same thing: What is your hobby?
#
# I was surprised at this, but it has been a very hard task because I think it may be an addiction. The words do not stand! [|startoftext|>  <|endoftitle|>   <|endoftext|>
# I was reading a book this morning, and was reading a section on the Holocaust. I asked the other person reading it, which do you think the "whites" were? [|startoftext|> What makes someone a Jew?
#
#
# A Jew is a person and they live in a city.
#
#
# If
#
# [210 | 724.77] loss=1.93 avg=2.00
# [220 | 756.98] loss=1.76 avg=1.99
# [230 | 789.15] loss=1.78 avg=1.98
# [240 | 821.32] loss=1.64 avg=1.96
# [250 | 853.47] loss=1.96 avg=1.96
# [260 | 885.67] loss=2.21 avg=1.97
# [270 | 917.85] loss=1.73 avg=1.96
# [280 | 949.82] loss=1.75 avg=1.95
# [290 | 981.72] loss=1.70 avg=1.94
# [300 | 1013.57] loss=1.70 avg=1.93
# [310 | 1045.40] loss=1.71 avg=1.92
# [320 | 1077.33] loss=1.67 avg=1.91
# [330 | 1109.27] loss=1.80 avg=1.91
# [340 | 1141.14] loss=2.09 avg=1.92
# [350 | 1173.07] loss=1.65 avg=1.91
# [360 | 1204.97] loss=2.12 avg=1.91
# [370 | 1236.86] loss=1.76 avg=1.91
# [380 | 1268.75] loss=2.01 avg=1.91
# [390 | 1300.65] loss=1.79 avg=1.91
# [400 | 1332.53] loss=1.99 avg=1.91
# ======== SAMPLE 1 ========
#  movie <|endoftext|>
# <|startoftext|> What did the doctor say to the nurse in the operating room? <|endoftitle|> You don't have to go in on your own. <|endoftext|>
# <|startoftext|> Why did the priest say they needed to make sure that the kids' ears worked before their first communion? <|endoftitle|> Because they were deaf! <|endoftext|>
# <|startoftext|> A new word has entered the dictionary and it's the name 'cucumber' <|endoftitle|>
# "I've been to the nursery and seen a cucumber."    "Its a good name."
# "It's a good name".
# "What about the ?"   "Oh, no, I see, I see."
# "This is a good father!  What's his dad doing?"
# "A    "It's a good dad!"
#
# "What's his dad doing?"
#
# "He's taking a nap."
#
# "Don't take a nap, you're a cumber."
# "You'll be taken back to jail."
# "That means c-cups, you'll be thrown in jail."
# "I can see you guys looking the other way."
# "Why not take a nap on the ground next to the crib, then!"
# "You'll always be a c-cup! You're the new C-cup!"
# "You know you're a c-cup..."
# "I feel a sense of pride whenever I put a c-cup on." <|endoftext|>
# <|startoftext|> Why did the priest say "If your hand burns, it should not be washed?" <|endoftitle|> I told him I'm not a priest and he laughed. <|endoftext|>
# <|startoftext|> What did the waiter say to the waiter? <|endoftitle|> How did you do? <|endoftext|>
# <|startoftext|> One of my friends got me <|endoftitle|> We were at a restaurant and my friend was sitting at his table. He got up and told the server, "Can I sit with you?" The waitress replied, "Sure." Then he got up and told the waiter that he wanted to sit at the bar. Her response, "I don't want a coffee." <|endoftext|>
# <|startoftext|> What did the father say to the children? <|endoftitle|> Do you always say, "Oh how sweet the mother is"? <|endoftext|>
# <|startoftext|> I can't get pregnant <|endoftitle|> It's never really happening!
#
# *gets interrupted*
#
# I can't have kids!
#
# It doesn't make any sense!
#
# It's an embarrassing situation
#
# But it's not me or my family!
#
# It's the doctor's wife!
#
# *gets interrupted*
#
# I couldn't bear to look at that picture.
#
# It looks so ugly!
#
# I don't want a pregnancy! <|endoftext|>
# <|startoftext|> Whats the first thing she said to the guys next door? <|endoftitle|> "Hey guys let's join the club"! <|endoftext|>
# <|startoftext|> We're in my dad's basement. <|endoftitle|> She just pulled some of his items out and walked off.  <|endoftext|>
# <|startoftext|> Why would someone steal a car from the garage sale? <|endoftitle|> Because it was stolen! <|endoftext|>
# <|startoftext|> I was in the process of buying a motorcycle at the bike shop... it's no longer available. <|endoftitle|> So I put a stop sign down in case they would go for it. There was a motorcycle dealer there with a few of them.
#
# It seems the motorcycle dealer had bought a new machine from the shop that was used by the old one.  He said, "This one is new, it's the best you've been offered." <|endoftext|>
# <|startoftext|> In a horror movie, there's the headless skeleton. <|endoftitle|> Then we get to see
#
# [410 | 1400.47] loss=1.67 avg=1.90
# [420 | 1432.39] loss=2.36 avg=1.92
# [430 | 1464.30] loss=1.66 avg=1.91
# [440 | 1496.17] loss=2.30 avg=1.92
# [450 | 1528.06] loss=2.10 avg=1.93
# [460 | 1560.00] loss=1.92 avg=1.93
# [470 | 1591.99] loss=1.73 avg=1.92
# [480 | 1624.03] loss=1.87 avg=1.92
# [490 | 1656.08] loss=1.88 avg=1.92
# [500 | 1688.05] loss=2.52 avg=1.93
# Saving checkpoint/dadjokes1/model-500
# [510 | 1729.64] loss=1.82 avg=1.93
# [520 | 1761.55] loss=1.63 avg=1.92
# [530 | 1793.47] loss=1.74 avg=1.92
# [540 | 1825.36] loss=1.69 avg=1.91
# [550 | 1857.25] loss=1.90 avg=1.91
# [560 | 1889.15] loss=1.92 avg=1.91
# [570 | 1921.02] loss=1.57 avg=1.91
# [580 | 1952.93] loss=1.72 avg=1.90
# [590 | 1984.78] loss=2.04 avg=1.90
# [600 | 2016.67] loss=1.69 avg=1.90
# ======== SAMPLE 1 ========
#
#
# The best thing about my Dad jokes?
#
# Yeah, but he doesn't mean it to be. It's a good thing he doesn't say it like a dad joke. [Sighs]. [Makes eye contact with dad]
#
# He never does.
#
# Don't be so hard on him. He works so long hours that he's never really done his bit.
#
# Yes, he does, but that does not make him a tough guy. [Sighs]. [Laughs]
# [Saw Dad] Did you know the last two characters on the show have been on the air for 7 years?
#
# No, but they're all dead. [Sighs]
#
# What else?
#
# He's got a daughter named "Jada."
#
# That's awesome.
#
# Ohhhhh!
#  [To Jadamaniac] Why don't you make that joke again?
#
# "Hey, Jada!"
#
# Yeah yeah yeah!
#
# Well, Jada is a pretty tough joke.
#
# The one about a "D" was a bit longer than I wanted it to be. But I didn't think the kids would like it. [Laughs]
#
# I didn't hear any complaints. :) [Pause]
#
# Do you think they'll ever catch up? [Pause}
#
# Maybe, just maybe. If I hear someone say it a hundred times, I may say something, [Laughs]
#
# I hope not.
#
# Why'd you pick that? [Laughs] *Sniffle* <|endoftext|>
# <|startoftext|> What do you call a giant fart? <|endoftitle|> A G-Flatulent. <|endoftext|>
# <|startoftext|> What do you call a guy who has a really high score on a sport? <|endoftitle|> A G-Score! <|endoftext|>
# <|startoftext|> I love my dad's jokes, but I sometimes wish I could explain them better than him. I just don't know where to draw the line. <|endoftitle|>
# 1) He can't take credit for anything, like I told him. 2) No big gummy bears have ever been a G-Score to me.  <|endoftext|>
# <|startoftext|> You know how there are so much times in the day you have to say "Oh no" and "Oh no, no"? <|endoftitle|> ... <|endoftext|>
# <|startoftext|> A dad joke about a duck: "I bet he's a big hit with the duck-staters." <|endoftitle|> My husband and I watched a movie today: "The Strain" <|endoftext|>
# <|startoftext|> Why do cats not get a job at McDonald's? <|endoftitle|> They prefer to run away in a ruff... <|endoftext|>
# <|startoftext|> What did the dog say when he was about to be fired from his job? <|endoftitle|> What does the wolf say to the cat? <|endoftext|>
# <|startoftext|> My mom wants to start a company on food security. It's a really big challenge. So I think we shall do it without her. I would have her as a guest. <|endoftitle|> [I'm having a really hard time with the metaphor]  <|endoftext|>
# <|startoftext|> One of our daughters asked: "Hey dad, is it okay if we eat in the park and not on the plane?" <|endoftitle|> My dad said, "If there's a lot more people here it'd be a big risk, but if it's small I'll let them be" <|endoftext|>
# <|startoftext|> I was going to give my grandpa the award for most expensive meal ever paid for with a credit card. <|endoftitle|> Then I realized it wasn't really my money. <|endoftext|>
# <|startoftext|> [NSFW] What's the difference between a chicken and a rooster? <|endoftitle|> One is a bird  <|endoftext|>
# <|startoftext|> I was going to eat at a restaurant but then asked the waiter there if I should change my mind because that was what they called "spaghettini".  So the conversation went on for a while. <|endoftitle|> [Walking up to the restaurant, looking for a table, I say] "What is a pizza parlor called
#
# [610 | 2084.99] loss=1.71 avg=1.90
# [620 | 2116.90] loss=1.79 avg=1.89
# [630 | 2148.76] loss=1.95 avg=1.89
# [640 | 2180.66] loss=1.61 avg=1.89
# [650 | 2212.53] loss=1.71 avg=1.88
# [660 | 2244.41] loss=1.82 avg=1.88
# [670 | 2276.24] loss=2.21 avg=1.89
# [680 | 2308.08] loss=2.16 avg=1.90
# [690 | 2339.90] loss=1.88 avg=1.90
# [700 | 2371.76] loss=2.23 avg=1.90
# [710 | 2403.63] loss=1.79 avg=1.90
# [720 | 2435.52] loss=1.69 avg=1.90
# [730 | 2467.39] loss=1.90 avg=1.90
# [740 | 2499.30] loss=2.06 avg=1.90
# [750 | 2531.18] loss=2.04 avg=1.90
# [760 | 2563.06] loss=1.86 avg=1.90
# [770 | 2594.98] loss=1.89 avg=1.90
# [780 | 2626.89] loss=1.84 avg=1.90
# [790 | 2658.71] loss=2.01 avg=1.90
# [800 | 2690.51] loss=1.92 avg=1.90
# ======== SAMPLE 1 ========
# 's best friend. <|endoftext|>
# <|startoftext|> I'm a bit surprised nobody said anything about the car that caught fire last year <|endoftitle|> I guess we are all fire victims <|endoftext|>
# <|startoftext|> What's the difference between the French and American ways of dressing? <|endoftitle|> White people have little yellow dresses. French people have little blue. <|endoftext|>
# <|startoftext|> What's a big guy's favourite colour? <|endoftitle|> Blue.  <|endoftext|>
# <|startoftext|> Whats a great fatherly joke <|endoftitle|> I made this up for myself <|endoftext|>
# <|startoftext|> When someone's eyes are closed, they are as good as a dead person <|endoftitle|> They are dead.  <|endoftext|>
# <|startoftext|> What's the biggest thing holding an elephant in your hand? <|endoftitle|> A long stick <|endoftext|>
# <|startoftext|> What do you call a fish with no legs? <|endoftitle|> A limp fish.  <|endoftext|>
# <|startoftext|> My son's favourite song says:
#
#
# Me: Dad, that's not a guitar
#
# Dad: Oh yes, it's a bass guitar
#
# Me: Well...
#
# Dad: Don't be silly son! No bass. No bass guitar. It's a bass bass bass bass bass guitar.  <|endoftitle|><|endoftext|>An international team of researchers have discovered some of the first genetic differences between plants. Credit: Wikimedia Commons
#
# Scientists have discovered that there are over 300 different types of chromosomes, some of which differ from each other in the number of copies and lengths they have.
#
# The team made the discovery by studying the chromosome count of seven species of flowering plants. These seven species are:
#
# Theories on what causes this chromosome count problem
#
# So the team started looking at the chromosomes of these seven other species in order to discover why there were so many of them, but was unable to confirm this theory.
# As they were unable to prove this theory, they decided to have some fun with it.
#
# They put the four kinds of chromosomes to the test. The four types of chromosomes were (1) a, b, c, and d.
#
# What was the difference between "a" and "b"?
#
# The "a" chromosome (which is located on chromosomes 3 and 4 in people) is a d.
#
# What was the difference between "c" and "d"?
#
# The "c" chromosome (which is located on chromosomes 1 and 2 in humans) is a d.
#
# What was the difference between "e" and "f"?
#
# The "e" chromosome (which is located on chromosomes 9-15 in humans) is a d.
#
# What did the four kinds of DNA do?
#
# They divided the chromosomes into a and e (the two letters in A that are found on chromosomes 4 and 15).
#
# What else can the four kinds of chromosomes do?
#
# They can get themselves sorted.
#
# This is no laughing matter.
# (Image Source)
# What did the researchers say?
#
# "Here's another one. We took a look at 'g' and 'g' is up on the top row.
# "What do you think, 'g' or 'g's'?
#
# "G' The number 1
#
# "G's The number 7
# "
#
# "The only thing you could tell what the difference is is on how much it gets me and I can tell it does the job."
#
# (Image Source)
# (Image Source)
# The following day, the DNA test showed that the four kinds of chromosomes are in a d.
# The following week, the DNA test was in a g and a, a, and a.
# I guess I'm in no way a scientist, but this was pretty entertaining to be sure.
# This is one of the funnier sections of my life.
# What do you call a man who makes a fortune in the fruit and vegetable business?
# The best-sellers.
# In other words, the first person to claim the plum is a first?
# What do you call a man who can name a tree after himself?
# The tree for the best.
# What is a tree and the best?
# A good man. <|endoftitle|>
# In conclusion<|endoftext|>If it isn't clear in advance, here it is.   I think I just hit a nerve.  This one is a bit longer, but not nearly as farfetched
#
# [810 | 2758.54] loss=2.35 avg=1.91
# [820 | 2790.44] loss=1.77 avg=1.91
# [830 | 2822.36] loss=1.61 avg=1.90
# [840 | 2854.26] loss=1.77 avg=1.90
# [850 | 2886.18] loss=1.72 avg=1.90
# [860 | 2918.05] loss=1.69 avg=1.89
# [870 | 2949.93] loss=1.92 avg=1.89
# [880 | 2981.84] loss=1.85 avg=1.89
# [890 | 3013.74] loss=1.62 avg=1.89
# [900 | 3045.61] loss=1.91 avg=1.89
# [910 | 3077.45] loss=1.93 avg=1.89
# [920 | 3109.30] loss=1.76 avg=1.89
# [930 | 3141.14] loss=1.90 avg=1.89
# [940 | 3172.97] loss=1.94 avg=1.89
# [950 | 3204.84] loss=2.00 avg=1.89
# [960 | 3236.70] loss=1.84 avg=1.89
# [970 | 3268.54] loss=2.05 avg=1.89
# [980 | 3300.38] loss=1.76 avg=1.89
# [990 | 3332.23] loss=1.62 avg=1.89
# [1000 | 3364.10] loss=1.84 avg=1.88
# Saving checkpoint/dadjokes1/model-1000
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# ======== SAMPLE 1 ========
# > <|endoftitle|> I was eating lunch with a friend and this guy walked up to everyone and said, "Hey, I've got the world's fastest man!" <|endoftext|>
# <|startoftext|> What do you call a guy in a suit who has a job? <|endoftitle|> A suit maker <|endoftext|>
# <|startoftext|> My friend told me my dad has some amazing hair skills - I was impressed. <|endoftitle|> I mean, come on! He's bald. <|endoftext|>
# <|startoftext|> Did you know the first human in the universe was a child? <|endoftitle|> He was born into a human-child-fatherhood <|endoftext|>
# <|startoftext|> Do you really think it's always raining behind this wall? <|endoftitle|> ... <|endoftext|>
# <|startoftext|> What is the difference between a doctor and a dentist? <|endoftitle|> A dentist has no need for antibiotics <|endoftext|>
# <|startoftext|> Some of the first movies shot in the ocean were made in the ocean <|endoftitle|>  <|endoftext|>
# <|startoftext|> If I want a new set of speakers, <|endoftitle|> I better replace the ones I already have... <|endoftext|>
# <|startoftext|> I was thinking of creating a parody of George Clooney's "Lift your Half-Pound" <|endoftitle|> But then I realized that George Clooney's voice was just like an octopus. <|endoftext|>
# <|startoftext|> How did the frog get to the top of the mountain? <|endoftitle|> With a frog summit <|endoftext|>
# <|startoftext|> If a bear is going to come to Canada and eat a cow... <|endoftitle|> The cow was going to give way to the bear and have to be fed. <|endoftext|>
# <|startoftext|> I made this joke to a guy at the airport, but nobody believed me. <|endoftitle|> He asked me if the jokes had to be on his check-in to make him stop, I told him its a bit of a joke but it's on my checklist <|endoftext|>
# <|startoftext|> I got a job at the local bakery, but its not much work for me. <|endoftitle|> Its just baking some bread. <|endoftext|>
# <|startoftext|> Where do you live in Iceland? <|endoftitle|> Icelanders <|endoftext|>
# <|startoftext|> My wife has told me "you are making your wife cry" <|endoftitle|> I say, "what"? <|endoftext|>
# <|startoftext|> When you're working on a roof <|endoftitle|> You always feel like it's in the ceiling <|endoftext|>
# <|startoftext|> What do you know of a car's engine? <|endoftitle|> There's a fuel pump in there <|endoftext|>
# <|startoftext|> When I was a kid, I ate cheese at dinner with my dad. <|endoftitle|> Then my mom and I would eat at another table. Then my dad asked "what's that for?" and my mom responded, "Chocolate."<|endoftext|>I was born in the United States of America and grew up in the UK.  <|endoftext|>
#
# <|startoftext|> What's in your drink maker, dad? <|endoftitle|> I said "It's the drink maker." <|endoftext|>
# <|startoftext|> I can't get down low <|endoftitle|> When I turn, the whole top of the tree falls down on me.  <|endoftext|>
# <|startoftext|> "What are you, a bear?" <|endoftitle|> Me: <|endoftext|>
# <|startoftext|> Why can't the car on the left slide? <|endoftitle|> A car on the left!  <|endoftext|>
# <|startoftext|> My wife told me to wash my face. <|endoftitle|> I replied:
#
# Well, you're still gonna feel your
#
# [1010 | 3440.06] loss=1.51 avg=1.88
# [1020 | 3472.03] loss=1.77 avg=1.88
# [1030 | 3503.96] loss=1.64 avg=1.87
# [1040 | 3535.90] loss=2.12 avg=1.88
# [1050 | 3567.86] loss=1.70 avg=1.87
# [1060 | 3599.78] loss=1.68 avg=1.87
# [1070 | 3631.78] loss=1.62 avg=1.87
# [1080 | 3663.75] loss=2.08 avg=1.87
# [1090 | 3695.76] loss=1.74 avg=1.87
# [1100 | 3727.72] loss=1.64 avg=1.87
# [1110 | 3759.66] loss=1.83 avg=1.86
# [1120 | 3791.57] loss=1.67 avg=1.86
# [1130 | 3823.48] loss=1.77 avg=1.86
# [1140 | 3855.39] loss=1.82 avg=1.86
# [1150 | 3887.36] loss=1.79 avg=1.86
# [1160 | 3919.34] loss=1.99 avg=1.86
# [1170 | 3951.32] loss=1.70 avg=1.86
# [1180 | 3983.23] loss=2.15 avg=1.86
# [1190 | 4015.15] loss=1.55 avg=1.86
# [1200 | 4047.08] loss=1.83 avg=1.86
# ======== SAMPLE 1 ========
#  me on Saturday night, but it was only a minute later when I found out that the guy had hit me with a hammer! <|endoftext|>
# <|startoftext|> How often should I leave the baby? <|endoftitle|> The less time you take to give him space. <|endoftext|>
# <|startoftext|> Why would you find a diamond in the sand? <|endoftitle|> Because he has no pockets. <|endoftext|>
# <|startoftext|> Why do you see aliens and not humans in the sky? <|endoftitle|> Because humans are always out there, hiding. I'm a good human-elder <|endoftext|>
# <|startoftext|> My wife likes to talk about how much of her family were born on November first, in the morning.  <|endoftitle|> "Well, you know the reason why my dad got my parents to sign the dotted line is because he was born on December first. I guess that's because he's the only one born on November first." <|endoftext|>
# <|startoftext|> What's the most overused phrase in Hollywood? <|endoftitle|> Ahh-rah.  <|endoftext|>
# <|startoftext|> The first day is usually the best <|endoftitle|> Especially if you're in the hospital.  <|endoftext|>
# <|startoftext|> What do you call it when the wind blows on your hair? <|endoftitle|> Rags <|endoftext|>
# <|startoftext|> I'm thinking about putting on my new bra and panties. <|endoftitle|>  But if I wear the wrong ones will they cut me? <|endoftext|>
# <|startoftext|> Where do you hear the sound of a bee being sting? <|endoftitle|> The wax <|endoftext|>
# <|startoftext|> What's up with the name of the British supergroup? <|endoftitle|> "Nashville" <|endoftext|>
# <|startoftext|> Why are people so good at taking pictures? <|endoftitle|> Because no one else can.... <|endoftext|>
# <|startoftext|> Is it the sun, suncream, sun cream and then suncream cream that really attracts people? <|endoftitle|> No, it's the dark that attracts people <|endoftext|>
# <|startoftext|> Why did the old man have a lot of children? <|endoftitle|> Cause he was so lazy.  <|endoftext|>
# <|startoftext|> I met my wife at the grocery store, she was an odd woman out. <|endoftitle|> But my wife is awesome! <|endoftext|>
# <|startoftext|> My girlfriend and I were hanging out at a bar.... <|endoftitle|> I said, "Do you guys know what the bar is called?"
#
# She replied, "What bar? A bar?" <|endoftext|>
# <|startoftext|> I was going to tell an embarrassing story that took place yesterday, but now I'm going to tell it tomorrow. <|endoftitle|> <|endoftext|>
# <|startoftext|> How many legs does your shoe have? <|endoftitle|> I got no legs. <|endoftext|>
# <|startoftext|> What's the difference between the sky and the ground? <|endoftitle|> The sky is made of stars, the ground is made of sand. <|endoftext|>
# <|startoftext|> What do you call an elephant that just ran away? <|endoftitle|> An elephant <|endoftext|>
# <|startoftext|> A man walks into a bar and says "please put a straw on your head." <|endoftitle|> The bartender replies "yeah, we have two straws here". <|endoftext|>
# <|startoftext|> Why is the sun a good sun? <|endoftitle|> Because it never sets. <|endoftext|>
# <|startoftext|> What makes a good man? <|endoftitle|> 1. An honest one. <|endoftext|>
# <|startoftext|> My daughter calls me a dad sometimes. <|endoftitle|> What?
#
#
#
# [1210 | 4115.87] loss=2.27 avg=1.86
# [1220 | 4147.79] loss=1.90 avg=1.86
# [1230 | 4179.65] loss=2.19 avg=1.87
# [1240 | 4211.53] loss=1.69 avg=1.87
# [1250 | 4243.41] loss=1.63 avg=1.86
# [1260 | 4275.28] loss=1.90 avg=1.86
# [1270 | 4307.11] loss=1.99 avg=1.87
# [1280 | 4338.95] loss=2.18 avg=1.87
# [1290 | 4370.81] loss=1.58 avg=1.87
# [1300 | 4402.70] loss=1.68 avg=1.86
# [1310 | 4434.56] loss=1.48 avg=1.86
# [1320 | 4466.41] loss=2.23 avg=1.86
# [1330 | 4498.27] loss=1.79 avg=1.86
# [1340 | 4530.15] loss=1.75 avg=1.86
# [1350 | 4562.05] loss=2.08 avg=1.86
# [1360 | 4593.93] loss=1.68 avg=1.86
# [1370 | 4625.78] loss=2.08 avg=1.86
# [1380 | 4657.69] loss=1.56 avg=1.86
# [1390 | 4689.57] loss=1.67 avg=1.86
# [1400 | 4721.41] loss=2.06 avg=1.86
# ======== SAMPLE 1 ========
# oftend, in reference to the movie "Transformers" (http://www.youtube.com/watch?v=jT4n3eR7cqW). <|endoftext|>
# <|startoftext|> How many apples can fit into a tub of water? <|endoftitle|> A little apple, a little apple, and a little apple. So then I thought, if you fill a little tub of water I've filled myself I might pee inside. <|endoftext|>
# <|startoftext|> As we were waiting to get in to the airport we had to wait for our checked bags to get to the gate. <|endoftitle|> I asked the stewardess "Is there a little girl in your luggage?" to which she replied, "No". <|endoftext|>
# <|startoftext|> What do you call a person who can't stop thinking about one thing all at once? <|endoftitle|> A Temptator. <|endoftext|>
# <|startoftext|> What do you call a person who smokes marijuana, but doesn't want to smoke...? <|endoftitle|> Smoker!
#
# My wife got in a whole line of "Smoker" and I was like "what? No one's Smoking on this plane, what has happened to your self-respect!?" <|endoftext|>
# <|startoftext|> My dad was really into making fun of my mom's legs <|endoftitle|> My dad was into making fun of my mom's legs
#
# My dad and I were on a trip to the mall one weekend, my mom brought some of her family with her. My dad was a large, redhead wearing a bright red tux. My mom was wearing a pair of pink heels. I was with my brother and my sister who is also a sister.
# My dad:
#
# "I know, it's a big tux". <|endoftext|>
# <|startoftext|> What type of shoes do your parents buy? <|endoftitle|> Shoes with no pockets <|endoftext|>
# <|startoftext|> My girlfriend asked if I could borrow some money for a week, so I said: "So you can borrow this month this?" <|endoftitle|> "yes", I said, and I got out my mobile phone.
# I handed my girlfriend my phone and said,  "I'll be there soon, so have some time with me."     <|endoftext|>
# <|startoftext|> I was recently told my friend would be killed today. <|endoftitle|> So I asked him who it was. He said, "It's an air raid," <|endoftext|>
# <|startoftext|> What kind of music do you want with your coffee? <|endoftitle|> Oolong!
#
# (I have my own personal Oolong song) <|endoftext|>
# <|startoftext|> A new law is going to keep me out of prison for 5 years, so I don't want to commit anything while I'm out. <|endoftitle|> I need to stay off my cell phone. <|endoftext|>
# <|startoftext|> What is used twice... once to get the other person out of trouble and again while being pursued by a lion? <|endoftitle|> A rope. <|endoftext|>
# <|startoftext|> What did the doctor say to his patient? <|endoftitle|> "You need to be careful with that arm"
#
# He said that was a very strong arm!  <|endoftext|>
# <|startoftext|> You want a haircut for your wedding? <|endoftitle|> I could do that, but I want to be a big boy before I give myself a haircut. <|endoftext|>
# <|startoftext|> Dad said we had a problem but we went over it. Guess what? It was solved. <|endoftitle|> That is. <|endoftext|>
# <|startoftext|> What do you call a cow that can talk? <|endoftitle|> A cow that has a problem  <|endoftext|>
# <|startoftext|> What do you call a cow that can speak three languages? <|endoftitle|> A bison cow  <|endoftext|>
# <|startoftext|> Do they make "diamond"? <|endoftitle|> No, but they
#
# [1410 | 4789.40] loss=1.69 avg=1.86
# [1420 | 4821.26] loss=2.03 avg=1.86
# [1430 | 4853.12] loss=1.97 avg=1.86
# [1440 | 4884.97] loss=1.51 avg=1.86
# [1450 | 4916.78] loss=1.67 avg=1.85
# [1460 | 4948.58] loss=1.70 avg=1.85
# [1470 | 4980.39] loss=1.85 avg=1.85
# [1480 | 5012.25] loss=2.04 avg=1.85
# [1490 | 5044.14] loss=1.99 avg=1.86
# [1500 | 5076.01] loss=1.82 avg=1.86
# Saving checkpoint/dadjokes1/model-1500
# [1510 | 5115.33] loss=1.78 avg=1.86
# [1520 | 5147.21] loss=1.60 avg=1.85
# [1530 | 5179.08] loss=1.85 avg=1.85
# [1540 | 5210.94] loss=1.67 avg=1.85
# [1550 | 5242.70] loss=1.76 avg=1.85
# [1560 | 5274.45] loss=1.80 avg=1.85
# [1570 | 5306.19] loss=1.79 avg=1.85
# [1580 | 5337.94] loss=1.67 avg=1.84
# [1590 | 5369.73] loss=1.71 avg=1.84
# [1600 | 5401.50] loss=1.67 avg=1.84
# ======== SAMPLE 1 ========
#  really? <|endoftitle|> I'm not good at it. But it's very, very easy for me. <|endoftext|>
# <|startoftext|> Why did the blind man walk on water? <|endoftitle|> Because he knew where to look... <|endoftext|>
# <|startoftext|> I was on a job interview and told my boss that I had a very bad English accent for a foreigner <|endoftitle|>
#
# She responded: I don't think you're doing that very well.
#
# "No, you're a great person you really are." <|endoftext|>
# <|startoftext|> I love it when my boss is kind <|endoftitle|> He's always smiling and waving his arms. <|endoftext|>
# <|startoftext|> Why did the horse eat all of the grapes in the garden? <|endoftitle|> Because there WAS grapes to be had. <|endoftext|>
# <|startoftext|> What type of meat do pigs like to eat? <|endoftitle|> "The meat of their mind." <|endoftext|>
# <|startoftext|> I was in the grocery store last night when I saw a new package of condoms for around $12. I knew this wasn't the real deal, so I pulled it out of the bin and bought it for $6.50. <|endoftitle|> That's how hard the real deal is! <|endoftext|>
# <|startoftext|> Do you want chocolate-brown-eyed baby deer? <|endoftitle|> No. Chocolate-grey-eyed baby. <|endoftext|>
# <|startoftext|> Why is the windmill so popular when it's windy? <|endoftitle|> Because of the wind-mill-wind-mom. <|endoftext|>
# <|startoftext|> What do you get if you cook pizza on an island? <|endoftitle|> Ice-pano. <|endoftext|>
# <|startoftext|> I told my son not to look at the lights. <|endoftitle|> He doesn't need to see much of any of it to realize that it's the lights he is looking at- he's totally in the wrong place. <|endoftext|>
# <|startoftext|> Did you hear about the duck that died and was found with its tongue hanging out of its mouth? <|endoftitle|> It was pronounced dead. <|endoftext|>
# <|startoftext|> How did the chicken cross the street? <|endoftitle|> It walked across the street! <|endoftext|>
# <|startoftext|> Where is the fastest submarine? <|endoftitle|> the fastestest submarine! <|endoftext|>
# <|startoftext|> What do you call a little baby dinosaur? <|endoftitle|> De-trio. <|endoftext|>
# <|startoftext|> What did the guy who was working on a remote control say to his boss? <|endoftitle|> "I'm still here so I guess we're still stuck here." <|endoftext|>
# <|startoftext|> I always tell people I don't know things. <|endoftitle|> People just get better with practice. <|endoftext|>
# <|startoftext|> I had to be honest with my girlfriend <|endoftitle|> she told me it was her job to tell her jokes.
#
# I laughed and told her I had no idea where she was working... <|endoftext|>
# <|startoftext|> I have a real problem. <|endoftitle|> I keep losing myself.  <|endoftext|>
# <|startoftext|> Every time I make a pot of coffee I always throw it in the microwave because it's the safest place to keep it. <|endoftitle|>  <|endoftext|>
# <|startoftext|> I tried to impress my wife with a picture of a woman that looked so perfect I thought it would be a bit of a pain in the butt to fix her... <|endoftitle|> But she's in for a rude awakening. <|endoftext|>
# <|startoftext|> What are you wearing? <|endoftitle|> A t-shirt.  <|endoftext|>
# <|startoftext|>
#
# [1610 | 5469.54] loss=1.53 avg=1.84
# [1620 | 5501.32] loss=1.58 avg=1.83
# [1630 | 5533.07] loss=1.94 avg=1.84
# [1640 | 5564.89] loss=1.69 avg=1.83
# [1650 | 5596.67] loss=1.79 avg=1.83
# [1660 | 5628.25] loss=1.81 avg=1.83
# [1670 | 5659.98] loss=1.74 avg=1.83
# [1680 | 5691.58] loss=1.78 avg=1.83
# [1690 | 5723.34] loss=2.20 avg=1.84
# [1700 | 5755.20] loss=1.68 avg=1.83
# [1710 | 5786.94] loss=1.69 avg=1.83
# [1720 | 5818.63] loss=1.60 avg=1.83
# [1730 | 5850.37] loss=1.65 avg=1.83
# [1740 | 5882.06] loss=2.05 avg=1.83
# [1750 | 5913.78] loss=1.74 avg=1.83
# [1760 | 5945.47] loss=1.77 avg=1.83
# [1770 | 5977.38] loss=1.64 avg=1.83
# [1780 | 6009.23] loss=1.76 avg=1.82
# [1790 | 6041.02] loss=1.86 avg=1.82
# [1800 | 6072.83] loss=1.72 avg=1.82
# ======== SAMPLE 1 ========
# FWendertown-The-Pizza-Delivery
#
# "Hey, you don't need a pizza delivery from me."
#
# "No, I just got some great pizza from a girl with a delivery"
#
# - - - - - - - - - - - - -
#
# Went to the store to get a new bottle of beer on my way out of my house. I found an empty one on the counter and got home and opened it but couldnt get to the glass.
#
# "I cant drink that, it gets soggy"
#
#
# <.<
#
# "Hey, where did you find that empty cup you cant drink?
#
# Well you just gotta find the faucet"  <.<
#
# "Dishwasher not my cup of tea <.<
#
# "It is your choice" <.<
#
# "The answer is the dishwasher" <.<
#
# "the answer is the cup" <.<
#
# "the answer is the dish" <.<
#
# "the dish is the answer" <.<
#
# "dish is the dish" <.<
#
# "the dish is the answer" <.<
#
# "the dish is the dish" <.<
#
# Oh, its so catchy <.<
# <
# < < <
#
# "Why cant you drink that from me? ?"
#
# "I cant drink that from you" <.<
#
# "I cant, because youre a pizza delivery driver" <.<
# "I cant, because I delivery from that delivery pizza..." <.<
# "I cant, because youre a delivery driver" <.<
# < < < < <<
# "I can not drive this car!" <.<
#  <
# "I cant even, I am delivery from this delivery pizza. How do I get your pizza?" <.<
# "I cant get your pizza, not delivery pizza" <.<
# "I cant get your pizza, not delivery pizza" <.<
# "I cant get your pizza, not delivery pizza" <.<
# "I cant get your pizza, not delivery pizza" <.<
# "I cant get your pizza, not delivery pizza" <.<
# "I cant get your pizza, not delivery pizza" <.<
# "I cant get your pizza, not deliver pizza" <.<
# "I cant get your pizza, not delivery pizza" <.<
# "I cant get your pizza, not delivery pizza" <.<
# "I cant get your pizza, not delivery pizza" <.<
# "I cant get your pizza, not delivery pizza" <.<
# "I cant get your pizza, not delivery pizza" <.<
# "I cant get your pizza, not delivery pizza" <.<
# "I cant get your pizza, not delivery pizza" <.<
# "I cant get your pizza, not delivery pizza" <.<
# "I cant get your pizza, not delivery pizza" <.<
# "I cant get your pizza, not delivery pizza" <.<
# "I cant get your pizza, not delivery pizza" <.< < < < < < < < < < < < < < < < < < < < < < < < < < < < < < < <
#
# What did the waiter say when I had a delivery of a pizza?
#
# "Now you can drink your coffee" <.<
#
# - - - - - - - - - - - - - - - - - - -
#
# Went out to the store today to get some fresh produce. I was wearing a shirt that says "Buy Fresh in the Market!"... I guess they must sell everything. <.<
#
# - - - - - - - - - - - - - - - - -
#
# This guy got me today, Ive been eating out my whole life so Ive always had an appreciation for the freshness that they put out. Ive always said Ive gotten better since Ive been working in stores. At least he's made my day with more of an effort. <.<
#
# - - - - - - - - - - - - - - - - - -
#
# A while ago when I was trying to cook a meal the waiter asked "Do you want some garlic, I need to use your spices" <.<
#
# - - - - - - - - - - - - - - - -
#
# So this dude just came back from the hospital with a shoulder injury. He came back from the hospital with a shoulder injury. I could have never put my foot down. <.<
#  < I can only assume it's from the hip. <.<
#  < <
# < < < < < < < < < < < < < < < < < < < < < < < <
#
# Now that'd be a nice one. <.<
#
# < < < < < < < < < < < < < < < < < < < < < < <
#
# [1810 | 6141.04] loss=1.56 avg=1.82
# [1820 | 6172.84] loss=1.65 avg=1.82
# [1830 | 6204.64] loss=1.85 avg=1.82
# [1840 | 6236.44] loss=1.64 avg=1.82
# [1850 | 6268.26] loss=1.91 avg=1.82
# [1860 | 6300.12] loss=1.82 avg=1.82
# [1870 | 6331.98] loss=1.99 avg=1.82
# [1880 | 6363.85] loss=1.94 avg=1.82
# [1890 | 6395.74] loss=2.08 avg=1.82
# [1900 | 6427.65] loss=2.14 avg=1.83
# [1910 | 6459.57] loss=1.71 avg=1.83
# [1920 | 6491.40] loss=2.10 avg=1.83
# [1930 | 6523.26] loss=2.18 avg=1.83
# [1940 | 6555.12] loss=1.70 avg=1.83
# [1950 | 6587.07] loss=1.63 avg=1.83
# [1960 | 6619.09] loss=1.81 avg=1.83
# [1970 | 6651.30] loss=2.08 avg=1.83
# [1980 | 6683.46] loss=1.76 avg=1.83
# [1990 | 6715.65] loss=1.77 avg=1.83
# [2000 | 6747.84] loss=1.91 avg=1.83
# Saving checkpoint/dadjokes1/model-2000
# ======== SAMPLE 1 ========
# .
#
# DAD: Yeah.
#
# ME3: what the heck i got you? <|endoftext|>
# <|startoftext|> What did the apple say to the banana at the party? <|endoftitle|> You're late! <|endoftext|>
# <|startoftext|> What do you call someone who wants to build a nuclear bomb? <|endoftitle|> An atomic bomber. <|endoftext|>
# <|startoftext|> Every morning I wake up and my wife asks if I did the morning routine <|endoftitle|> It doesn't make any sense.  <|endoftext|>
# <|startoftext|> A man walks into a bar... <|endoftitle|> Barman: What a surprise! What do you think of this beer?
#
# Man: Well... I don't know, I've never been before <|endoftext|>
# <|startoftext|> Every time I make a joke about Christmas <|endoftitle|> Dad: What are we having for dinner? <|endoftext|>
# <|startoftext|> What did the tree say to his children? <|endoftitle|> I'll make the wreath for you.
#
# Dad: I guess you better be careful with that one. <|endoftext|>
# <|startoftext|> My friend was talking about how he just bought a new computer... <|endoftitle|> Then he said <|endoftext|>
# <|startoftext|> My son was telling me how he wanted a dog... <|endoftitle|> ... but it has the word dog in its name. <|endoftext|>
# <|startoftext|> What do you call someone who just got married? <|endoftitle|> The nuptial bride <|endoftext|>
# <|startoftext|> Theres a doctor behind the counter at the pharmacy who will do a quick test for you if your prescription has expired... <|endoftitle|> It's for your eyes!
#
# (thanks to my son) <|endoftext|>
# <|startoftext|> What Do you call a tree that has been around for 100 years? <|endoftitle|> A Tree Of Life.
# It's the only tree I've ever come across that was dead! <|endoftext|>
# <|startoftext|> My friend told me she's starting college this fall. <|endoftitle|> I told her it's a full time job. My kid has his own classes on campus, but I guess he can learn anything without classes. <|endoftext|>
# <|startoftext|> What do you call white powder? <|endoftitle|> White-Powder <|endoftext|>
# <|startoftext|> What's a duck's favorite snack? <|endoftitle|> A duck punch. <|endoftext|>
# <|startoftext|> I was out with family the other Monday and saw some men leaving their favorite restaurant. <|endoftitle|> The restaurant owner got very angry and said "I've got to go to the restroom!"
#
# To which my friend said "but you're still hungry"
#
#
#
# My response:
#  <|endoftext|>
# <|startoftext|> What do you call a cow that has been in the news every day since the last report? <|endoftitle|> A news cow <|endoftext|>
# <|startoftext|> How do you tell someone who hasn't taken an aspirin for a long time to take an aspirin again? <|endoftitle|> Take them to a doctor <|endoftext|>
# <|startoftext|> I was asked to come up with a pun to save your life. <|endoftitle|> I replied, "Well, I don't know, I'm not a puncier."  <|endoftext|>
# <|startoftext|> What is the best way to stop the sun? <|endoftitle|> Bring it back... <|endoftext|>
# <|startoftext|> What do you call a cow who is a lawyer? <|endoftitle|> A cow-defending lawyer! <|endoftext|>
# <|startoftext|> Why don't horses like to pee in their pants? <|endoftitle|> Because when they pee in their pants, they get a buck. <|endoftext|>
# <|startof
#
# [2010 | 6824.79] loss=1.96 avg=1.83
# [2020 | 6857.03] loss=1.92 avg=1.83
# [2030 | 6889.27] loss=2.01 avg=1.84
# [2040 | 6921.47] loss=1.84 avg=1.84
# [2050 | 6953.60] loss=1.96 avg=1.84
# [2060 | 6985.83] loss=2.02 avg=1.84
# [2070 | 7018.00] loss=1.68 avg=1.84
# [2080 | 7050.13] loss=1.77 avg=1.84
# [2090 | 7082.30] loss=1.97 avg=1.84
# [2100 | 7114.50] loss=1.89 avg=1.84
# [2110 | 7146.68] loss=1.41 avg=1.83
# [2120 | 7178.92] loss=1.98 avg=1.84
# [2130 | 7211.11] loss=1.95 avg=1.84
# [2140 | 7243.31] loss=1.87 avg=1.84
# [2150 | 7275.55] loss=1.59 avg=1.84
# [2160 | 7307.79] loss=2.03 avg=1.84
# [2170 | 7339.98] loss=1.86 avg=1.84
# [2180 | 7372.12] loss=1.98 avg=1.84
# [2190 | 7404.25] loss=1.82 avg=1.84
# [2200 | 7436.34] loss=1.62 avg=1.84
# ======== SAMPLE 1 ========
#  a lot of people that would like to see this movie become a movie. I've been told this movie is a no-sell.
#
# I don't really care. Why do people want to see a movie about this, where was the first film on Mars?
#
# I'll talk to my dad about this later. <|endoftext|>
# <|startoftext|> "Did you know," I started my dad joke, "We have a few things on the same page?" <|endoftitle|> "And we don't think I even need to add anything." <|endoftext|>
# <|startoftext|> Got my grandma the other day and gave her a big hug <|endoftitle|> "Don't ever be the guy who gets all teary eyed in a barber shop or a drugstore."
#
# -me
#
# *sniffle in the chest*
#
# "I said you smell."
#
# "How? I was afraid you might have some cocaine in your lungs."
#
# "Well, you can be addicted."
#
# "What? Like I said, it's not your mother's cough syrup. I thought it might be a bit much." <|endoftext|>
# <|startoftext|> My dad just got a job as a "Culture" writer at a Chinese restaurant. <|endoftitle|> "I'm Chinese!"
# "Great! I'll just have you make me some food." <|endoftext|>
# <|startoftext|> My 3yo says he wants to be a comedian. That's funny! <|endoftitle|> But I don't think he's ready for this.
#
#
# "So, let me tell you about my dad, and what he's done for me:" <|endoftext|>
# <|startoftext|> My dad just got the job at a Chinese restaurant <|endoftitle|> "So, I hear you've worked in the Chinese restaurant scene, and then I have you say this one, which is very sad, but very true," he asked.
#
# "Well, I don't think the rest of them got the joke." <|endoftext|>
# <|startoftext|> After my wife started using her cell phone to text me from home... <|endoftitle|> She's been doing this to me since she became a parent this past summer. We are really getting annoyed at my wife and don't care about my dad.
#
# "Why do you make this such a big deal, honey?" <|endoftext|>
# <|startoftext|> My dad got a job at the Chinese restaurant... <|endoftitle|> He made a lot of new friends there, was super nice at the counter, and knew so much! <|endoftext|>
# <|startoftext|> The other day my dad sat me down and told me about the restaurant that I'd seen at an airport a few weeks ago. <|endoftitle|> "There must have been one thing...there was no tablecloths." <|endoftext|>
# <|startoftext|> My dad and I talked about our new house. <|endoftitle|> What's a little-known fact about the house, is that it's completely air-con... <|endoftext|>
# <|startoftext|> Dad was talking to another dad about a joke he gave me earlier in our day. <|endoftitle|> "You've got to get people to believe in your joke."
#
# *I laughed! I laughed at the most ridiculous thing I've seen all day. I had just seen it in a store that did a lot of things right!
# >"Yeah, they're selling books with your name on them!"
#
# That was a laugh-out-loud moment for my whole day. <|endoftext|>
# <|startoftext|> I've been talking about my wife's body with her dad, but it's getting old. <|endoftitle|> They're trying to start a family...
#
# ...It's going to be a big family-size family. <|endoftext|>
# <|startoftext|> I'm a dad in the kitchen, too <|endoftitle|> When asked if I'd be interested in cooking for someone special... <|endoftext|>
# <|startoftext|> My dad texted me: "Hey, you know why I'm buying a car? Because your dad told me to." <|endoftitle|> I asked for the numbers and to ask what they were <|endoftext|>
# <|startoftext|> Today I woke up to
#
# [2210 | 7505.00] loss=1.89 avg=1.84
# [2220 | 7537.26] loss=2.10 avg=1.84
# [2230 | 7569.46] loss=1.39 avg=1.84
# [2240 | 7601.65] loss=1.91 avg=1.84
# [2250 | 7633.85] loss=1.62 avg=1.83
# [2260 | 7666.06] loss=1.90 avg=1.83
# [2270 | 7698.25] loss=1.69 avg=1.83
# [2280 | 7730.48] loss=1.96 avg=1.83
# [2290 | 7762.71] loss=1.55 avg=1.83
# [2300 | 7794.95] loss=1.52 avg=1.83
# [2310 | 7827.00] loss=2.04 avg=1.83
# [2320 | 7859.14] loss=1.70 avg=1.83
# [2330 | 7891.41] loss=1.72 avg=1.83
# [2340 | 7923.65] loss=1.81 avg=1.83
# [2350 | 7955.89] loss=1.57 avg=1.82
# [2360 | 7988.13] loss=2.00 avg=1.83
# [2370 | 8020.41] loss=1.62 avg=1.82
# [2380 | 8052.69] loss=1.56 avg=1.82
# [2390 | 8084.94] loss=1.59 avg=1.82
# [2400 | 8117.18] loss=1.58 avg=1.82
# ======== SAMPLE 1 ========
# oftitle|> He was one of the first people to make a "narrative based" album, using a different name each disc. <|endoftext|>
# <|startoftext|> Did your mum drink all her milk as she slept? <|endoftitle|> It wasn't like the other nights <|endoftext|>
# <|startoftext|> If I have to go to prison for being a child rapist, what will I do if I get my hands on a gun? <|endoftitle|> I will shoot myself! <|endoftext|>
# <|startoftext|> A man was having a bit of trouble with his beard when he got his little brother's attention. <|endoftitle|> "We need to get us some new hair!"
#
# "Okay, why not do a twirly-dance?"
#
# "Because a twirl can't get you anywhere!" <|endoftext|>
# <|startoftext|> Whats for dinner? <|endoftitle|> A sandwich <|endoftext|>
# <|startoftext|> I told a joke about an old person who didnt have time to be a father <|endoftitle|> It was a very light wit <|endoftext|>
# <|startoftext|> What do you call a giant, blue-eyed octopus with no legs? <|endoftitle|> A fish, a tetra-octopus! <|endoftext|>
# <|startoftext|> I saw a guy with a giant rubber stamp around his neck <|endoftitle|> I said to him "What's his name?" <|endoftext|>
# <|startoftext|> Did you hear the one about a magician who made two copies of himself? <|endoftitle|> He was playing to two people at once <|endoftext|>
# <|startoftext|> Did you hear the one about the giant, black sheep with no face <|endoftitle|> No fur, it's no fur <|endoftext|>
# <|startoftext|> I really hate to tell jokes in class... <|endoftitle|> ...but I have to tell one a time, the teacher always stops me. <|endoftext|>
# <|startoftext|> Did you hear that the police arrested a person for trying to kill his stepmother? <|endoftitle|> She did the same thing as the man who tried to kill Mrs. Kew <|endoftext|>
# ...
# [4110 | 13978.01] loss=1.66 avg=1.77
# [4120 | 14010.17] loss=1.56 avg=1.77
# [4130 | 14042.28] loss=1.61 avg=1.77
# [4140 | 14074.47] loss=1.73 avg=1.77
# [4150 | 14106.61] loss=2.09 avg=1.77
# [4160 | 14138.84] loss=1.56 avg=1.77
# [4170 | 14171.02] loss=1.72 avg=1.77
# [4180 | 14203.19] loss=1.64 avg=1.77
# [4190 | 14235.32] loss=2.14 avg=1.77
# [4200 | 14267.35] loss=1.53 avg=1.77
# ======== SAMPLE 1 ========
#  into the forest?
#
# (Fantastic movie!) <|endoftext|>
# <|startoftext|> Got my sister <|endoftitle|> Sis:  Can you get me a haircut?
#
# Me:  Sure, but you better not do it at sunset
#  <|endoftext|>
# <|startoftext|> Why was the cat so happy after losing her claws? <|endoftitle|> She got more feli-cat than any other cat! <|endoftext|>
# <|startoftext|> How do you catch a black hole? <|endoftitle|> Put a black hole on your head, and use a black light! (And a red one, too) <|endoftext|>
# <|startoftext|> You know how many people died in the Great Flood? <|endoftitle|> Three. <|endoftext|>
# <|startoftext|> What do you call a good man with a wheelchair? <|endoftitle|> Walter. <|endoftext|>
# <|startoftext|> What do you call someone who gets a new house? <|endoftitle|> Renovation <|endoftext|>
# <|startoftext|> I was eating an eggplant with my dad and he said, "don't eat it" <|endoftitle|> I said, "It's tender" <|endoftext|>
# <|startoftext|> I can tell my son is really happy when I tell him he has so much fun doing nothing. <|endoftitle|> "I'm not so much a dunce as I am a dunce! *sniffle*" <|endoftext|>
# <|startoftext|> How do you tell if your dog is going on a rampage? <|endoftitle|> He'll probably pick something up and throw it at you. <|endoftext|>
# <|startoftext|> What do you call a guy that steals people's shoes? <|endoftitle|> Bootlegged. <|endoftext|>
# <|startoftext|> What did the cowboy say to the other one after he caught a coyote? <|endoftitle|> I'm ready to run <|endoftext|>
# <|startoftext|> The first time I got pregnant I fell down a deep hole. <|endoftitle|> All for nothing! <|endoftext|>
# <|startoftext|> Why wasn't the dog afraid of heights? <|endoftitle|> Because it's an under houseiffer! <|endoftext|>
# <|startoftext|> What do you call it when the weather is really cold? <|endoftitle|> Ice cold <|endoftext|>
# <|startoftext|> Why was the guy who got stuck in the mud so proud? <|endoftitle|> He was proud with mud on his own!! <|endoftext|>
# <|startoftext|> I love my wife. <|endoftitle|> I think shes the only gal she knows <|endoftext|>
# <|startoftext|> I had a problem with my wife <|endoftitle|> I had to go to the doctor and i found out she was asexual. <|endoftext|>
# <|startoftext|> I met a guy with an ugly mustache in class, <|endoftitle|> He didnt seem to make much of an impression. <|endoftext|>
# <|startoftext|> The problem with writing your mind on paper. <|endoftitle|>  <|endoftext|>
# <|startoftext|> What do you call a guy with no teeth? <|endoftitle|> A toothless guy. <|endoftext|>
# <|startoftext|> What did they call the new cat? <|endoftitle|> A chewie <|endoftext|>
# <|startoftext|> Some people like to name their kids. I just call mine Billy, but it rhymes with my name. <|endoftitle|> My wife is really cool now because she can say this in Swedish. <|endoftext|>
# <|startoftext|> I tried to tell my friend what we should do to improve the world <|endoftitle|> And I didn't quite succeed. <|endoftext|>
# <|startoftext|> I tried to convince my boss that our department was doing very poorly by adding a new
#
# [4210 | 14336.00] loss=1.76 avg=1.77
# [4220 | 14368.13] loss=1.45 avg=1.77
# [4230 | 14400.28] loss=1.50 avg=1.76
# [4240 | 14432.46] loss=1.45 avg=1.76
# [4250 | 14464.62] loss=1.94 avg=1.76
# [4260 | 14496.80] loss=1.78 avg=1.76
# [4270 | 14529.00] loss=1.66 avg=1.76
# [4280 | 14561.12] loss=1.51 avg=1.76
# [4290 | 14593.15] loss=2.24 avg=1.76
# [4300 | 14625.26] loss=1.75 avg=1.76
# [4310 | 14657.48] loss=1.70 avg=1.76
# [4320 | 14689.77] loss=1.77 avg=1.76
# [4330 | 14722.05] loss=1.76 avg=1.76
# [4340 | 14754.36] loss=1.61 avg=1.76
# [4350 | 14786.67] loss=1.25 avg=1.76
# [4360 | 14818.94] loss=1.39 avg=1.75
# [4370 | 14851.26] loss=1.80 avg=1.75
# [4380 | 14883.50] loss=2.06 avg=1.76
# [4390 | 14915.80] loss=1.61 avg=1.75
# [4400 | 14948.11] loss=1.82 avg=1.76
# ======== SAMPLE 1 ========
# startoftext|> When was the last time that anyone was upset about how a certain cereal sucked? <|endoftitle|> It was a Dont Crunch. <|endoftext|>
# <|startoftext|> I was in class in the third grade and a classmate was getting in trouble for playing "Mama Tried" backwards. I asked how she was and to stop being such a pushy girl. <|endoftitle|>
#
# I was right in.
#
# It was then that my friends "Mum Tried" back on me. <|endoftext|>
# <|startoftext|> Got a friend <|endoftitle|> At the gym i saw him passing by, after an hour of cardio he looked over and said "How's your training?" i responded by "Its in the gym. I'm not a gym rat." <|endoftext|>
# <|startoftext|> Do you know why I don't follow the news on Twitter? <|endoftitle|> Because of the crazy headline at the end. <|endoftext|>
# <|startoftext|> My dad has to eat dinner by a fire cracker before school today. <|endoftitle|> He says he shouldnt smoke a puff. <|endoftext|>
# <|startoftext|> Why is the moon so dark? <|endoftitle|> It's because its behind in its orbits <|endoftext|>
# <|startoftext|> Every single car I've ever owned has an alarm on them... <|endoftitle|> All of these things have alarms.  <|endoftext|>
# <|startoftext|> What do you call a horse with six legs? <|endoftitle|> A foal on the ground. <|endoftext|>
# <|startoftext|> Why can't the elephant stand still? <|endoftitle|> Because of its waist. <|endoftext|>
# <|startoftext|> Where are you most scared by? <|endoftitle|> In the dark! <|endoftext|>
# <|startoftext|> My kid used to make fun of me at birth every morning <|endoftitle|> But I was fine with it because I knew then he was just a day-care!  <|endoftext|>
# <|startoftext|> My dog has been acting funny. <|endoftitle|> Its his 'paws day.' <|endoftext|>
# <|startoftext|> I was watching my daughter playing with her bike and I asked her "what's your favorite bike?" <|endoftitle|> She said, "My Favorite One" <|endoftext|>
# <|startoftext|> My wife told me to wear high heels... <|endoftitle|> I didn't understand it when she said that. <|endoftext|>
# <|startoftext|> I went to the doctor and asked if I'm pregnant, because I don't hear that in the Philippines. <|endoftitle|> They told me they don't work there.   <|endoftext|>
# <|startoftext|> What kind of dog eats cheese? <|endoftitle|> I'm not sure but we say Gouda!  <|endoftext|>
# <|startoftext|> What is this old ad for "The Cat Lady"? <|endoftitle|> A little kitten cat. <|endoftext|>
# <|startoftext|> I know where a fish lives... <|endoftitle|> He's in the tank <|endoftext|>
# <|startoftext|> Why do people keep having to change their shoes? <|endoftitle|> It wears out after a while.   <|endoftext|>
# <|startoftext|> I just finished reading a book that's about the difference between a bad joke and a really bad joke <|endoftitle|> I cant put it down.  <|endoftext|>
# <|startoftext|> What do you call a small frog that can't stand your oar? <|endoftitle|> An awkward-pony. <|endoftext|>
# <|startoftext|> I saw a man being thrown in jail today. <|endoftitle|> Did you know that most of the time people who throw people in jail are innocent? <|endoftext|>
# <|startoftext|> I had a dream yesterday, and I don't know why.
#
# [4410 | 15017.87] loss=1.79 avg=1.76
# [4420 | 15050.13] loss=1.57 avg=1.75
# [4430 | 15082.23] loss=1.46 avg=1.75
# [4440 | 15114.31] loss=1.44 avg=1.75
# [4450 | 15146.50] loss=1.86 avg=1.75
# [4460 | 15178.68] loss=1.53 avg=1.75
# [4470 | 15210.92] loss=1.85 avg=1.75
# [4480 | 15243.17] loss=1.54 avg=1.75
# [4490 | 15275.41] loss=1.77 avg=1.75
# [4500 | 15307.61] loss=1.48 avg=1.74
# Saving checkpoint/dadjokes1/model-4500
# [4510 | 15347.18] loss=1.55 avg=1.74
# [4520 | 15379.42] loss=1.79 avg=1.74
# [4530 | 15411.71] loss=1.53 avg=1.74
# [4540 | 15444.01] loss=1.58 avg=1.74
# [4550 | 15476.28] loss=1.51 avg=1.74
# [4560 | 15508.55] loss=1.68 avg=1.74
# [4570 | 15540.83] loss=1.53 avg=1.73
# [4580 | 15573.17] loss=1.68 avg=1.73
# [4590 | 15605.40] loss=1.47 avg=1.73
# [4600 | 15637.70] loss=1.69 avg=1.73
# ======== SAMPLE 1 ========
# itle|> This is how I make my noodles... <|endoftext|>
# <|startoftext|> Me and my son got a new toy yesterday. <|endoftitle|> My wife was watching the tv and I told her that I had given him a new toy and that it was a baby robot that he could play with. My wife has an OCD type of OCD where she only buys new toys and just recently had a child of her own that she purchased for a little less than a pound.
# Wife: I need to get the child removed now. I just bought a carload of baby steps too.
# Me: I'll get him. <|endoftext|>
# <|startoftext|> "Do those trees count as plants?" <|endoftitle|> "Not quite. The fruit trees count as fruit" <|endoftext|>
# <|startoftext|> Where does the tooth fairy get her money? <|endoftitle|> From the town on the bill!  <|endoftext|>
# <|startoftext|> Every time someone walks past a graveyard... <|endoftitle|>  "Where's the guy with the ghostly grin?" "Well, where is he hanging?" -All the dead people, except the guy wearing a skull cap <|endoftext|>
# <|startoftext|> What did the snail say to the tooth fairy? <|endoftitle|> *sigh* <|endoftext|>
# <|startoftext|> Why can't you hear your grandfather playing cricket? <|endoftitle|> He's doing a long run.  <|endoftext|>
# <|startoftext|> Today my dad stopped by the car and gave me a piece of the past that was left behind the other day <|endoftitle|> The car had the pieces for him to take with him to the future.  <|endoftext|>
# <|startoftext|> What did the dog say? <|endoftitle|> What did the dog say to the cat?  *sigh*
#
# "Can I have a look at you" <|endoftext|>
# <|startoftext|> What did the dog say to the cat? <|endoftitle|> "I can go where you go." <|endoftext|>
# <|startoftext|> It was nice having my own family while I was a kid... <|endoftitle|> But when I went upstairs, and started crying... <|endoftext|>
# <|startoftext|> What do you call a cow with no sense of direction? <|endoftitle|> A moo-derm. <|endoftext|>
# <|startoftext|> Why did the cowboy fall in the well? <|endoftitle|> He was in his 'splash! <|endoftext|>
# <|startoftext|> I have trouble sleeping at night ... <|endoftitle|> The lights just never make me feel any better. <|endoftext|>
# <|startoftext|> In the bathroom yesterday I asked the guy that bought me a new toilet for free to let me take the toilet plunger out and see if I found it useful. I was told no. It was already installed. <|endoftitle|> I've taken it out before too. But I guess I just need to be a better father. <|endoftext|>
# <|startoftext|> I saw a guy buying an iPhone at a drugstore today. <|endoftitle|> He was getting high with a $200 charger.
#
# I said, "You know the iPhone's not your problem, but yours is." <|endoftext|>
# <|startoftext|> What kind of cheese should kids be allowed to eat <|endoftitle|> "Cheeze" <|endoftext|>
# <|startoftext|> I was reading a book on French wine <|endoftitle|> I was so thirsty I had to turn down the book... <|endoftext|>
# <|startoftext|> I bought a horse <|endoftitle|> My wife told me not to buy a horse because they have such a high mortality rate.
# She said, he just doesn't know when he dies. <|endoftext|>
# <|startoftext|> How does a man with a broken finger treat his wife? <|endoftitle|> She's a sissiere. <|endoftext|>
# <|startoftext|> How does a
#
# [4610 | 15706.66] loss=1.68 avg=1.73
# [4620 | 15738.95] loss=1.60 avg=1.73
# [4630 | 15771.21] loss=1.56 avg=1.73
# [4640 | 15803.37] loss=1.69 avg=1.73
# [4650 | 15835.52] loss=1.38 avg=1.72
# [4660 | 15867.71] loss=1.83 avg=1.72
# [4670 | 15899.94] loss=1.63 avg=1.72
# [4680 | 15932.17] loss=1.61 avg=1.72
# [4690 | 15964.44] loss=1.40 avg=1.72
# [4700 | 15996.75] loss=1.66 avg=1.72
# [4710 | 16029.07] loss=1.60 avg=1.72
# [4720 | 16061.34] loss=1.99 avg=1.72
# [4730 | 16093.74] loss=1.58 avg=1.72
# [4740 | 16126.01] loss=1.95 avg=1.72
# [4750 | 16158.28] loss=1.66 avg=1.72
# [4760 | 16190.59] loss=1.61 avg=1.72
# [4770 | 16222.88] loss=1.56 avg=1.72
# [4780 | 16255.22] loss=1.75 avg=1.72
# [4790 | 16287.58] loss=1.80 avg=1.72
# [4800 | 16319.94] loss=1.96 avg=1.72
# ======== SAMPLE 1 ========
#  did not know a word of english and had to find a dictionary? <|endoftitle|> You don't make it down the stairs... <|endoftext|>
# <|startoftext|> My dad went on a road trip with his daughter. <|endoftitle|> She was very sad but did not see the humor. <|endoftext|>
# <|startoftext|> Where do you put a sheep in the rain? <|endoftitle|> On a dam <|endoftext|>
# <|startoftext|> You could tell a doctor was a pretty good doctor. <|endoftitle|> They'd say, "My wife is pregnant" and then leave the hospital. <|endoftext|>
# <|startoftext|> You can't say that the Pope is under contract with the church <|endoftitle|> He's just a Catholic person. <|endoftext|>
# <|startoftext|> My 5 year old asked if I have any ice cream. <|endoftitle|> I said no. She's not getting a scoop until she's 8. <|endoftext|>
# <|startoftext|> So I have a friend who wants to go off some more on a high. <|endoftitle|> We're going on a date. We're going to have a few laughs. <|endoftext|>
# <|startoftext|> Did you know that there has been a mass shooting at a candy factory? <|endoftitle|> There is no candy left!  <|endoftext|>
# <|startoftext|> Do you know what a bird-cicle is? <|endoftitle|> It is a bird-corner.  <|endoftext|>
# <|startoftext|> Wife: "You know my baby will not have food or water when we fly back to Canada!" <|endoftitle|> Husband: "No, that's food for later! <|endoftext|>
# <|startoftext|> Who is the coolest guy in the zoo? <|endoftitle|> Wally. <|endoftext|>
# <|startoftext|> What is a fish named in French? <|endoftitle|> Flé <|endoftext|>
# <|startoftext|> What do you call a guy who wears glasses? <|endoftitle|> A eye-glassesman <|endoftext|>
# <|startoftext|> What is the funniest sound in nature? <|endoftitle|> A bark!
#
# What happens when a bear gets tired of food? He falls asleep in the food.  <|endoftext|>
# <|startoftext|> A bird that flies is actually more comfortable than a duck. <|endoftitle|> Because it doesnt matter if it is wet, cold or dry. <|endoftext|>
# <|startoftext|> I just went to the dentist <|endoftitle|> I think its time to get a second opinion  <|endoftext|>
# <|startoftext|> I hate when people tell me to be careful. <|endoftitle|> Sometimes Im not. <|endoftext|>
# <|startoftext|> My ex girlfriend has been cheating on me since my last girlfriend. It has become a long game. <|endoftitle|> It's like they're always going through that cycle. <|endoftext|>
# <|startoftext|> If you want to run in two months, you only need one hour. <|endoftitle|>  <|endoftext|>
# <|startoftext|> What kind of coffee does the skeleton like? <|endoftitle|> A latte <|endoftext|>
# <|startoftext|> I used to get a lot of weird looks from strangers when I used to work as a mime. <|endoftitle|> Now none of them recognize me. <|endoftext|>
# <|startoftext|> What do you call a group of ducks in a prison? <|endoftitle|> A gang of girds <|endoftext|>
# <|startoftext|> What do you call a group of ducks in a prison? <|endoftitle|> A gang of geese  <|endoftext|>
# <|startoftext|> Have you heard about the new movie about the famous Italian chef? <|endoftitle|> It had an Italian cast and was made in Italy. <|
#
# [4810 | 16389.02] loss=1.73 avg=1.72
# [4820 | 16421.35] loss=2.05 avg=1.72
# [4830 | 16453.72] loss=1.94 avg=1.73
# [4840 | 16486.07] loss=1.87 avg=1.73
# [4850 | 16518.34] loss=1.72 avg=1.73
# [4860 | 16550.67] loss=1.99 avg=1.73
# [4870 | 16583.00] loss=1.95 avg=1.73
# [4880 | 16615.30] loss=1.85 avg=1.73
# [4890 | 16647.60] loss=1.36 avg=1.73
# [4900 | 16679.90] loss=1.58 avg=1.73
# [4910 | 16712.24] loss=2.00 avg=1.73
# [4920 | 16744.56] loss=1.45 avg=1.73
# [4930 | 16776.91] loss=2.19 avg=1.73
# [4940 | 16809.22] loss=1.98 avg=1.73
# [4950 | 16841.54] loss=2.09 avg=1.74
# [4960 | 16873.79] loss=2.11 avg=1.74
# [4970 | 16905.90] loss=1.97 avg=1.74
# [4980 | 16938.01] loss=1.61 avg=1.74
# [4990 | 16970.36] loss=1.64 avg=1.74
# [5000 | 17002.74] loss=2.09 avg=1.75
# Saving checkpoint/dadjokes1/model-5000

# %% [markdown]
# After the model is trained, you can copy the checkpoint folder to your own Google Drive.
#
# If you want to download it to your personal computer, it's strongly recommended you copy it there first, then download from Google Drive. The checkpoint folder is copied as a `.rar` compressed file; you can download it and uncompress it locally.

# %%
gpt2.copy_checkpoint_to_gdrive(run_name='dadjokes1')

# %% [markdown]
# You're done! Feel free to go to the **Generate Text From The Trained Model** section to generate text based on your retrained model.

# %% [markdown]
# ## Load a Trained Model Checkpoint
#
# Running the next cell will copy the `.rar` checkpoint file from your Google Drive into the Colaboratory VM.

# %%
gpt2.copy_checkpoint_from_gdrive(run_name='dadjokes1')

# %% [markdown]
# The next cell will allow you to load the retrained model checkpoint + metadata necessary to generate text.
#
# **IMPORTANT NOTE:** If you want to rerun this cell, **restart the VM first** (Runtime -> Restart Runtime). You will need to rerun imports but not recopy files.

# %%
sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, run_name='dadjokes1')
# Out:
# Loading checkpoint checkpoint/dadjokes1/model-1000
# INFO:tensorflow:Restoring parameters from checkpoint/dadjokes1/model-1000

# %% [markdown]
# ## Generate Text From The Trained Model
#
# After you've trained the model or loaded a retrained model from checkpoint, you can now generate text. `generate` generates a single text from the loaded model.

# %%
gpt2.generate(sess, run_name='dadjokes1')

# %% [markdown]
# If you're creating an API based on your model and need to pass the generated text elsewhere, you can do `text = gpt2.generate(sess, return_as_list=True)[0]`
#
# You can also pass in a `prefix` to the generate function to force the text to start with a given character sequence and generate text from there (good if you add an indicator when the text starts).
#
# You can also generate multiple texts at a time by specifing `nsamples`. Unique to GPT-2, you can pass a `batch_size` to generate multiple samples in parallel, giving a massive speedup (in Colaboratory, set a maximum of 20 for `batch_size`).
#
# Other optional-but-helpful parameters for `gpt2.generate` and friends:
#
# *  **`length`**: Number of tokens to generate (default 1023, the maximum)
# * **`temperature`**: The higher the temperature, the crazier the text (default 0.7, recommended to keep between 0.7 and 1.0)
# * **`top_k`**: Limits the generated guesses to the top *k* guesses (default 0 which disables the behavior; if the generated output is super crazy, you may want to set `top_k=40`)
# * **`top_p`**: Nucleus sampling: limits the generated guesses to a cumulative probability. (gets good results on a dataset with `top_p=0.9`)
# * **`truncate`**: Truncates the input text until a given sequence, excluding that sequence (e.g. if `truncate='<|endoftext|>'`, the returned text will include everything before the first `<|endoftext|>`). It may be useful to combine this with a smaller `length` if the input texts are short.
# *  **`include_prefix`**: If using `truncate` and `include_prefix=False`, the specified `prefix` will not be included in the returned text.

# %%
# gpt2.generate(sess,
#               length=250,
#               temperature=0.7,
#               prefix="<|startoftext|>",
#               truncate="<|endoftext|>",
#               include_prefix=False,
#               nsamples=5,
#               batch_size=5,
#               )[0]

# TEST
print()
print()

title = gpt2.generate(sess,
              length=50,
              temperature=0.7,
              prefix="<|startoftext|>",
              truncate="<|endoftitle|>",
              include_prefix=False,
              nsamples=1,
              batch_size=1,
              return_as_list=True,
              run_name='dadjokes1',
              )[0]
body = gpt2.generate(sess,
              length=50,
              temperature=0.7,
              prefix=title,
              truncate="<|endoftext|>",
              include_prefix=False,
              nsamples=1,
              batch_size=1,
              return_as_list=True,
              run_name='dadjokes1',
              )[0]

print('Title:', title)
print('Body:', body)
# Out:
# Title:  What do you call a fatty bee?
# Body: A bee-o!

# %% [markdown]
# For bulk generation, you can generate a large amount of text to a file and sort out the samples locally on your computer. The next cell will generate a generated text file with a unique timestamp.
#
# You can rerun the cells as many times as you want for even more generated texts!

# %%
gen_file = 'gpt2_gentext_{:%Y%m%d_%H%M%S}.txt'.format(datetime.utcnow())

gpt2.generate_to_file(sess,
                      destination_path=gen_file,
                      length=500,
                      temperature=0.7,
                      nsamples=10000,
                      batch_size=20
                      )

# %%
# may have to run twice to get file to download
files.download(gen_file)

# %% [markdown]
# # Etcetera
#
# If the notebook has errors (e.g. GPU Sync Fail), force-kill the Colaboratory virtual machine and restart it with the command below:

# %%
# !kill -9 -1
